# %%
import numpy as np
import pandas as pd

# %%
institutions_df = pd.read_csv(
    'data/Most-Recent-Cohorts-Institution.csv.gz',
    usecols=[
        'OPEID6',
        'INSTNM',
        'CITY',
        'STABBR',
        'FTFTPCTPELL',
        'TUITIONFEE_IN',
        'TUITIONFEE_OUT',
        'ADM_RATE',
        'NPT4_PUB',
        'NPT4_PRIV',
        'NPT41_PUB',
        'NPT41_PRIV',
        'NPT45_PUB',
        'NPT45_PRIV',
        'MD_EARN_WNE_P10',
        'C100_4',
    ],
    low_memory=False
)

institutions_df
# Out:
#       OPEID6                                             INSTNM        CITY  \
# 0       1002                           Alabama A & M University      Normal
# 1       1052                University of Alabama at Birmingham  Birmingham
# 2      25034                                 Amridge University  Montgomery
# 3       1055                University of Alabama in Huntsville  Huntsville
# 4       1005                           Alabama State University  Montgomery
# ...      ...                                                ...         ...
# 6657    3329  Pennsylvania State University-Penn State Wilke...      Lehman
# 6658    3329      Pennsylvania State University-Penn State York        York
# 6659    3329  Pennsylvania State University-Penn State Great...     Malvern
# 6660    3329  Pennsylvania State University-Penn State Harri...  Middletown
# 6661    3329  Pennsylvania State University-Penn State Brand...       Media
#
# ...

# %%
fields_of_study_df = pd.read_csv(
    'data/FieldOfStudyData1718_1819_PP.csv.gz',
    usecols=[
        'OPEID6',
        'INSTNM',
        'CREDDESC',
        'CIPDESC',
        'CONTROL',
    ],
    low_memory=False
)

fields_of_study_df
# Out:
#         OPEID6                          INSTNM              CONTROL  \
# 0         1002        Alabama A & M University               Public
# 1         1002        Alabama A & M University               Public
# 2         1002        Alabama A & M University               Public
# 3         1002        Alabama A & M University               Public
# 4         1002        Alabama A & M University               Public
# ...        ...                             ...                  ...
# 224844   42640  California Southern University  Private, for-profit
# 224845   42640  California Southern University  Private, for-profit
# 224846   42753            Zion Massage College  Private, for-profit
# 224847   42837  Oregon Coast Community College               Public
# 224848   42840  Gather 4 Him Christian College   Private, nonprofit
#
#                                                   CIPDESC  \
# 0                                   Agriculture, General.
# ...

# %%
institutions_df['OPEID6'].value_counts()
# Out:
# OPEID6
# 1459     75
# 2456     42
# 22606    26
# 23068    24
# 3329     24
#          ..
# 2567      1
# 2560      1
# 2566      1
# 2563      1
# 42928     1
# Name: count, Length: 5252, dtype: int64

# %%
institutions_df[institutions_df['OPEID6'] == 1459]
# Out:
#       OPEID6                                         INSTNM         CITY  \
# 609     1459        Strayer University-District of Columbia   Washington
# 3426    1459                    Strayer University-Virginia    Arlington
# 4278    1459                    Strayer University-Maryland     Suitland
# 4544    1459                   Strayer University-Tennessee      Memphis
# 4545    1459                Strayer University-Pennsylvania      Trevose
# ...      ...                                            ...          ...
# 6576    1459                  Strayer University-Cedar Hill   Cedar Hill
# 6577    1459                Strayer University-North Dallas       Dallas
# 6578    1459                 Strayer University-San Antonio  San Antonio
# 6579    1459                    Strayer University-Stafford     Stafford
# 6580    1459  Strayer University - Northwest Houston Campus      Houston
#
#      STABBR  ADM_RATE  NPT4_PUB  NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  \
# ...

# %%
institutions_df['INSTNM'].value_counts()
# Out:
# INSTNM
# Cortiva Institute                                      6
# Jersey College                                         6
# Columbia College                                       5
# Arthur's Beauty College                                4
# Unitek College                                         4
#                                                       ..
# Otsego Area BOCES-Practical Nursing Program            1
# Orange County Community College                        1
# Onondaga Community College                             1
# Ohr Hameir Theological Seminary                        1
# Pennsylvania State University-Penn State Brandywine    1
# Name: count, Length: 6530, dtype: int64

# %%
institutions_df[institutions_df['INSTNM'] == 'Cortiva Institute']
# Out:
#       OPEID6             INSTNM             CITY STABBR  ADM_RATE  NPT4_PUB  \
# 550    23166  Cortiva Institute         Cromwell     CT       NaN       NaN
# 662    22796  Cortiva Institute   St. Petersburg     FL       NaN       NaN
# 2871   37663  Cortiva Institute  King of Prussia     PA       NaN       NaN
# 4012   30086  Cortiva Institute    Pompano Beach     FL       NaN       NaN
# 4333   32963  Cortiva Institute        Linthicum     MD       NaN       NaN
# 4386   30086  Cortiva Institute         Maitland     FL       NaN       NaN
#
#       NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  TUITIONFEE_IN  \
# 550     27625.0        NaN        NaN     26888.0     30209.0            NaN
# 662     21107.0        NaN        NaN     20723.0         NaN            NaN
# 2871    20349.0        NaN        NaN     19801.0     22582.0            NaN
# 4012    20918.0        NaN        NaN     20539.0     23796.0            NaN
# ...

# %%
cnt = institutions_df.groupby(by=['OPEID6', 'INSTNM'])['OPEID6'].count()
cnt
# Out:
# OPEID6  INSTNM
# 1002    Alabama A & M University                               1
# 1003    Faulkner University                                    1
# 1004    University of Montevallo                               1
# 1005    Alabama State University                               1
# 1007    Central Alabama Community College                      1
#                                                               ..
# 42928   Mason Anthony School of Cosmetology Arts & Sciences    1
# 42932   The Professional Cosmetology Academy                   1
# 42933   Hackensack Meridian School of Medicine                 1
# 42934   Oak Valley College                                     1
# 42953   Pathways College                                       1
# Name: OPEID6, Length: 6597, dtype: int64

# %%
cnt[cnt > 1]
# Out:
# OPEID6  INSTNM
# 2456    Columbia College - Waynesville                          2
# 2474    Kansas City University                                  2
# 2973    Gaston College                                          2
# 3674    Stevens-Henager College                                 3
# 4009    Mesabi Range College                                    2
# 4692    Dorsey College-Roseville                                2
# 5007    West Virginia Junior College-United Career Institute    2
# 6461    Saint Elizabeth College of Nursing                      2
# 7780    New Castle School of Trades                             2
# 9284    Brittany Beauty Academy                                 2
# 9618    Tulsa Welding School-Jacksonville                       2
# 11940   ICPR Junior College                                     2
# 11941   American University of Puerto Rico                      2
# 13088   Capri Beauty College                                    2
# ...

# %%
institutions_df[(institutions_df['OPEID6'] == 41341) & (institutions_df['INSTNM'] == 'Jersey College')]
# Out:
#       OPEID6          INSTNM          CITY STABBR  ADM_RATE  NPT4_PUB  \
# 4907   41341  Jersey College     Teterboro     NJ    0.3425       NaN
# 6555   41341  Jersey College         Tampa     FL       NaN       NaN
# 6556   41341  Jersey College         Ewing     NJ       NaN       NaN
# 6557   41341  Jersey College  Jacksonville     FL       NaN       NaN
# 6558   41341  Jersey College       Sunrise     FL       NaN       NaN
# 6559   41341  Jersey College         Largo     FL       NaN       NaN
#
#       NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  TUITIONFEE_IN  \
# 4907    24276.0        NaN        NaN     23653.0     27664.0            NaN
# 6555        NaN        NaN        NaN         NaN         NaN            NaN
# 6556        NaN        NaN        NaN         NaN         NaN            NaN
# 6557        NaN        NaN        NaN         NaN         NaN            NaN
# 6558        NaN        NaN        NaN         NaN         NaN            NaN
# ...

# %%
cnt = institutions_df.groupby(by=['OPEID6', 'INSTNM', 'STABBR', 'CITY'])['OPEID6'].count()
cnt
# Out:
# OPEID6  INSTNM                                               STABBR  CITY
# 1002    Alabama A & M University                             AL      Normal            1
# 1003    Faulkner University                                  AL      Montgomery        1
# 1004    University of Montevallo                             AL      Montevallo        1
# 1005    Alabama State University                             AL      Montgomery        1
# 1007    Central Alabama Community College                    AL      Alexander City    1
#                                                                                       ..
# 42928   Mason Anthony School of Cosmetology Arts & Sciences  OH      Hilliard          1
# 42932   The Professional Cosmetology Academy                 TX      Laredo            1
# 42933   Hackensack Meridian School of Medicine               NJ      Nutley            1
# 42934   Oak Valley College                                   CA      Rialto            1
# ...

# %%
cnt[cnt > 1].sum() / 2
# Out:
# np.float64(14.0)

# %%
institutions_df[(institutions_df['OPEID6'] == 2456) & (institutions_df['INSTNM'] == 'Columbia College - Waynesville') & (institutions_df['STABBR'] == 'MO')]
# Out:
#       OPEID6                          INSTNM         CITY STABBR  ADM_RATE  \
# 6312    2456  Columbia College - Waynesville  Waynesville     MO       NaN
# 6316    2456  Columbia College - Waynesville  Waynesville     MO       NaN
#
#       NPT4_PUB  NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  \
# 6312       NaN        NaN        NaN        NaN         NaN         NaN
# 6316       NaN        NaN        NaN        NaN         NaN         NaN
#
#       TUITIONFEE_IN  TUITIONFEE_OUT  MD_EARN_WNE_P10  C100_4  FTFTPCTPELL
# 6312         8112.0          8112.0              NaN     NaN          NaN
# 6316         8112.0          8112.0              NaN     NaN          NaN

# %%
len(institutions_df) - institutions_df.count()
# Out:
# OPEID6                0
# INSTNM                0
# CITY                  0
# STABBR                0
# ADM_RATE           4702
# NPT4_PUB           4834
# NPT4_PRIV          3097
# NPT41_PUB          4839
# NPT45_PUB          5358
# NPT41_PRIV         3156
# NPT45_PRIV         4853
# TUITIONFEE_IN      2832
# TUITIONFEE_OUT     2832
# MD_EARN_WNE_P10    1637
# C100_4             4655
# FTFTPCTPELL        1123
# dtype: int64

# %%
len(institutions_df)
# Out:
# 6662

# %%
dedup = institutions_df.drop_duplicates()
dedup
# Out:
#       OPEID6                                             INSTNM        CITY  \
# 0       1002                           Alabama A & M University      Normal
# 1       1052                University of Alabama at Birmingham  Birmingham
# 2      25034                                 Amridge University  Montgomery
# 3       1055                University of Alabama in Huntsville  Huntsville
# 4       1005                           Alabama State University  Montgomery
# ...      ...                                                ...         ...
# 6657    3329  Pennsylvania State University-Penn State Wilke...      Lehman
# 6658    3329      Pennsylvania State University-Penn State York        York
# 6659    3329  Pennsylvania State University-Penn State Great...     Malvern
# 6660    3329  Pennsylvania State University-Penn State Harri...  Middletown
# 6661    3329  Pennsylvania State University-Penn State Brand...       Media
#
# ...

# %%
dedup[(dedup['OPEID6'] == 2456) & (dedup['INSTNM'] == 'Columbia College - Waynesville') & (dedup['STABBR'] == 'MO')]
# Out:
#       OPEID6                          INSTNM         CITY STABBR  ADM_RATE  \
# 6312    2456  Columbia College - Waynesville  Waynesville     MO       NaN
#
#       NPT4_PUB  NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  \
# 6312       NaN        NaN        NaN        NaN         NaN         NaN
#
#       TUITIONFEE_IN  TUITIONFEE_OUT  MD_EARN_WNE_P10  C100_4  FTFTPCTPELL
# 6312         8112.0          8112.0              NaN     NaN          NaN

# %%
cnt = dedup.groupby(by=['OPEID6', 'INSTNM', 'STABBR', 'CITY'])['OPEID6'].count()
cnt
# Out:
# OPEID6  INSTNM                                               STABBR  CITY
# 1002    Alabama A & M University                             AL      Normal            1
# 1003    Faulkner University                                  AL      Montgomery        1
# 1004    University of Montevallo                             AL      Montevallo        1
# 1005    Alabama State University                             AL      Montgomery        1
# 1007    Central Alabama Community College                    AL      Alexander City    1
#                                                                                       ..
# 42928   Mason Anthony School of Cosmetology Arts & Sciences  OH      Hilliard          1
# 42932   The Professional Cosmetology Academy                 TX      Laredo            1
# 42933   Hackensack Meridian School of Medicine               NJ      Nutley            1
# 42934   Oak Valley College                                   CA      Rialto            1
# ...

# %%
cnt[cnt > 1]
# Out:
# OPEID6  INSTNM                                  STABBR  CITY
# 2973    Gaston College                          NC      Dallas          2
# 4692    Dorsey College-Roseville                MI      Roseville       2
# 6461    Saint Elizabeth College of Nursing      NY      Utica           2
# 9618    Tulsa Welding School-Jacksonville       FL      Jacksonville    2
# 20983   Western Technical College               TX      El Paso         2
# 23313   Interactive College of Technology       TX      Houston         2
# 30353   Southern Careers Institute-San Antonio  TX      San Antonio     2
# 31150   Arizona College of Nursing-Tempe        AZ      Tempe           2
# 37143   Trend Barber College                    TX      Houston         2
# 41176   Larry's Barber College                  IL      Chicago         2
# 41697   Unitek College                          CA      Fremont         2
# 42052   Wade Gordon Hairdressing Academy        TX      Amarillo        2
# ...

# %%
dedup[(dedup['OPEID6'] == 2973) & (dedup['INSTNM'] == 'Gaston College') & (dedup['STABBR'] == 'NC')]
# Out:
#       OPEID6          INSTNM    CITY STABBR  ADM_RATE  NPT4_PUB  NPT4_PRIV  \
# 2350    2973  Gaston College  Dallas     NC       NaN   12994.0        NaN
# 6352    2973  Gaston College  Dallas     NC       NaN       NaN        NaN
#
#       NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  TUITIONFEE_IN  \
# 2350    12100.0        NaN         NaN         NaN         2704.0
# 6352        NaN        NaN         NaN         NaN         2704.0
#
#       TUITIONFEE_OUT  MD_EARN_WNE_P10  C100_4  FTFTPCTPELL
# 2350          8848.0          30512.0     NaN       0.5777
# 6352          8848.0          30512.0     NaN          NaN

# %%
institutions_df['STABBR'].value_counts(ascending=False).head(1)
# Out:
# STABBR
# CA    705
# Name: count, dtype: int64

# %%
institutions_df.groupby(by=['STABBR', 'CITY'])['OPEID6'].count().sort_values(ascending=False).head(1)
# Out:
# STABBR  CITY
# NY      New York    81
# Name: OPEID6, dtype: int64

# %%
institutions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6662 entries, 0 to 6661
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OPEID6           6662 non-null   int64
#  1   INSTNM           6662 non-null   object
#  2   CITY             6662 non-null   object
#  3   STABBR           6662 non-null   object
#  4   ADM_RATE         1960 non-null   float64
#  5   NPT4_PUB         1828 non-null   float64
#  6   NPT4_PRIV        3565 non-null   float64
#  7   NPT41_PUB        1823 non-null   float64
#  8   NPT45_PUB        1304 non-null   float64
#  9   NPT41_PRIV       3506 non-null   float64
#  10  NPT45_PRIV       1809 non-null   float64
#  11  TUITIONFEE_IN    3830 non-null   float64
#  12  TUITIONFEE_OUT   3830 non-null   float64
#  13  MD_EARN_WNE_P10  5025 non-null   float64
#  14  C100_4           2007 non-null   float64
#  15  FTFTPCTPELL      5539 non-null   float64
# ...

# %%
institutions_df.memory_usage(deep=True).sum()
# Out:
# np.int64(1945775)

# %%
institutions_df['STABBR'] = institutions_df['STABBR'].astype('category')

# %%
institutions_df['CITY'] = institutions_df['CITY'].astype('category')

# %%
institutions_df.memory_usage(deep=True).sum()
# Out:
# np.int64(1453116)

# %%
institutions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6662 entries, 0 to 6661
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OPEID6           6662 non-null   int64
#  1   INSTNM           6662 non-null   object
#  2   CITY             6662 non-null   category
#  3   STABBR           6662 non-null   category
#  4   ADM_RATE         1960 non-null   float64
#  5   NPT4_PUB         1828 non-null   float64
#  6   NPT4_PRIV        3565 non-null   float64
#  7   NPT41_PUB        1823 non-null   float64
#  8   NPT45_PUB        1304 non-null   float64
#  9   NPT41_PRIV       3506 non-null   float64
#  10  NPT45_PRIV       1809 non-null   float64
#  11  TUITIONFEE_IN    3830 non-null   float64
#  12  TUITIONFEE_OUT   3830 non-null   float64
#  13  MD_EARN_WNE_P10  5025 non-null   float64
#  14  C100_4           2007 non-null   float64
#  15  FTFTPCTPELL      5539 non-null   float64
# ...

# %%
institutions_df.head()
# Out:
#    OPEID6                               INSTNM        CITY STABBR  ADM_RATE  \
# 0    1002             Alabama A & M University      Normal     AL    0.8965
# 1    1052  University of Alabama at Birmingham  Birmingham     AL    0.8060
# 2   25034                   Amridge University  Montgomery     AL       NaN
# 3    1055  University of Alabama in Huntsville  Huntsville     AL    0.7711
# 4    1005             Alabama State University  Montgomery     AL    0.9888
#
#    NPT4_PUB  NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  \
# 0   15529.0        NaN    14694.0    20483.0         NaN         NaN
# 1   16530.0        NaN    13443.0    19717.0         NaN         NaN
# 2       NaN    17618.0        NaN        NaN     17385.0         NaN
# 3   17208.0        NaN    13631.0    19862.0         NaN         NaN
# 4   19534.0        NaN    19581.0    17559.0         NaN         NaN
#
#    TUITIONFEE_IN  TUITIONFEE_OUT  MD_EARN_WNE_P10  C100_4  FTFTPCTPELL
# ...

# %%
fields_of_study_df.head()
# Out:
#    OPEID6                    INSTNM CONTROL                       CIPDESC  \
# 0    1002  Alabama A & M University  Public         Agriculture, General.
# 1    1002  Alabama A & M University  Public              Animal Sciences.
# 2    1002  Alabama A & M University  Public  Food Science and Technology.
# 3    1002  Alabama A & M University  Public  Food Science and Technology.
# 4    1002  Alabama A & M University  Public  Food Science and Technology.
#
#            CREDDESC
# 0  Bachelors Degree
# 1  Bachelors Degree
# 2  Bachelors Degree
# 3   Master's Degree
# 4   Doctoral Degree

# %%
fields_of_study_df['CREDDESC'].hist(figsize=(20, 7), grid=False)
# Out:
# <Axes: >

# %%
fields_of_study_df.loc[fields_of_study_df['CREDDESC'] == 'Bachelors Degree', 'INSTNM'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
fields_of_study_df.loc[fields_of_study_df['CREDDESC'] == 'Bachelors Degree', 'INSTNM'].value_counts().head(1)
# Out:
# INSTNM
# Westminster College    165
# Name: count, dtype: int64

# %%
fields_of_study_df.loc[fields_of_study_df['CREDDESC'].isin(['Master\'s Degree', 'Doctoral Degree']), 'INSTNM'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
fields_of_study_df['CREDDESC'].value_counts()
# Out:
# CREDDESC
# Bachelors Degree                        71901
# Associate's Degree                      43706
# Undergraduate Certificate or Diploma    43615
# Master's Degree                         37939
# Doctoral Degree                         12494
# Graduate/Professional Certificate       11135
# First Professional Degree                2311
# Post-baccalaureate Certificate           1748
# Name: count, dtype: int64

# %%
fields_of_study_df.loc[fields_of_study_df['CREDDESC'].isin(['Master\'s Degree', 'Doctoral Degree']), 'INSTNM'].value_counts().head(1)
# Out:
# INSTNM
# University of Washington-Seattle Campus    237
# Name: count, dtype: int64

# %%
fields_of_study_df.head()
# Out:
#    OPEID6                    INSTNM CONTROL                       CIPDESC  \
# 0    1002  Alabama A & M University  Public         Agriculture, General.
# 1    1002  Alabama A & M University  Public              Animal Sciences.
# 2    1002  Alabama A & M University  Public  Food Science and Technology.
# 3    1002  Alabama A & M University  Public  Food Science and Technology.
# 4    1002  Alabama A & M University  Public  Food Science and Technology.
#
#            CREDDESC
# 0  Bachelors Degree
# 1  Bachelors Degree
# 2  Bachelors Degree
# 3   Master's Degree
# 4   Doctoral Degree

# %%
bachelors = fields_of_study_df[fields_of_study_df['CREDDESC'] == 'Bachelors Degree'].groupby(by=['INSTNM'])['OPEID6'].count()
bachelors.name = 'bachelor_cnt'

# %%
bachelors
# Out:
# INSTNM
# AI Miami International University of Art and Design     8
# ASA College                                             5
# ATA College                                             1
# ATI College-Norwalk                                     1
# Aarhus University                                       1
#                                                        ..
# York College of Pennsylvania                           50
# York St John University                                 4
# York University                                         8
# Young Harris College                                   24
# Youngstown State University                            83
# Name: bachelor_cnt, Length: 3006, dtype: int64

# %%
doctors = fields_of_study_df[fields_of_study_df['CREDDESC'].isin(['Master\'s Degree', 'Doctoral Degree'])].groupby(by=['INSTNM'])['OPEID6'].count()
doctors.name = 'doctoral_cnt'

# %%
doctors
# Out:
# INSTNM
# A T Still University of Health Sciences                13
# AI Miami International University of Art and Design     2
# AOMA Graduate School of Integrative Medicine            2
# Aarhus University                                      14
# Abertay University                                      1
#                                                        ..
# York College                                            2
# York College of Pennsylvania                            4
# York St John University                                 4
# York University                                         7
# Youngstown State University                            42
# Name: doctoral_cnt, Length: 2487, dtype: int64

# %%
joined = pd.merge(left=bachelors, right=doctors, left_index=True, right_index=True, indicator=True, how='left')
joined = joined.reset_index()
joined = joined[joined['_merge'] == 'left_only']

# %%
len(joined['INSTNM'].drop_duplicates(keep='first'))
# Out:
# 923

# %%
joined = pd.merge(left=bachelors, right=doctors, left_index=True, right_index=True, indicator=True, how='right')
joined = joined.reset_index()
joined = joined[joined['_merge'] == 'right_only']
len(joined['INSTNM'].drop_duplicates(keep='first'))
# Out:
# 404

# %%
len(fields_of_study_df[(fields_of_study_df['CREDDESC'] == 'Bachelors Degree') & (fields_of_study_df['CIPDESC'].str.contains('Computer Science'))].groupby('INSTNM')['OPEID6'].count())
# Out:
# 762

# %%
fields_of_study_df[(fields_of_study_df['CREDDESC'] == 'Bachelors Degree') & (fields_of_study_df['CIPDESC'].str.contains('Computer Science'))].groupby('CONTROL')['OPEID6'].count().sort_values(ascending=False)
# Out:
# CONTROL
# Private, nonprofit     501
# Public                 273
# Foreign                 32
# Private, for-profit     18
# Name: OPEID6, dtype: int64

# %%
fields_of_study_df[(fields_of_study_df['CREDDESC'] == 'Bachelors Degree') & (fields_of_study_df['CIPDESC'].str.contains('Computer Science'))].groupby('CONTROL')['OPEID6'].count().plot.pie()
# Out:
# <Axes: ylabel='OPEID6'>

# %%
institutions_df.head()
# Out:
#    OPEID6                               INSTNM        CITY STABBR  ADM_RATE  \
# 0    1002             Alabama A & M University      Normal     AL    0.8965
# 1    1052  University of Alabama at Birmingham  Birmingham     AL    0.8060
# 2   25034                   Amridge University  Montgomery     AL       NaN
# 3    1055  University of Alabama in Huntsville  Huntsville     AL    0.7711
# 4    1005             Alabama State University  Montgomery     AL    0.9888
#
#    NPT4_PUB  NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  \
# 0   15529.0        NaN    14694.0    20483.0         NaN         NaN
# 1   16530.0        NaN    13443.0    19717.0         NaN         NaN
# 2       NaN    17618.0        NaN        NaN     17385.0         NaN
# 3   17208.0        NaN    13631.0    19862.0         NaN         NaN
# 4   19534.0        NaN    19581.0    17559.0         NaN         NaN
#
#    TUITIONFEE_IN  TUITIONFEE_OUT  MD_EARN_WNE_P10  C100_4  FTFTPCTPELL
# ...

# %%
bachelor_cs = fields_of_study_df[(fields_of_study_df['CREDDESC'] == 'Bachelors Degree') & (fields_of_study_df['CIPDESC'].str.contains('Computer Science'))][['OPEID6', 'INSTNM', 'CONTROL']]
bachelor_cs
# Out:
#         OPEID6                           INSTNM             CONTROL
# 360       1005         Alabama State University              Public
# 671       8310  Auburn University at Montgomery              Public
# 1110      1003              Faulkner University  Private, nonprofit
# 1936      1033               Oakwood University  Private, nonprofit
# 2040      1036               Samford University  Private, nonprofit
# ...        ...                              ...                 ...
# 223531   30914         University of Wollongong             Foreign
# 223619   30961              La Trobe University             Foreign
# 223971   34353        Anglia  Ruskin University             Foreign
# 224154   35173           University of Brighton             Foreign
# 224709   41839                CETYS Universidad             Foreign
#
# [824 rows x 3 columns]

# %%
pd.merge(left=bachelor_cs, right=institutions_df[['OPEID6', 'TUITIONFEE_OUT']], how='inner', on='OPEID6')['TUITIONFEE_OUT'].agg(['min', 'median', 'mean', 'max'])
# Out:
# min        3154.000000
# median    24320.000000
# mean      26996.482002
# max       61671.000000
# Name: TUITIONFEE_OUT, dtype: float64

# %%
pd.merge(left=bachelor_cs, right=institutions_df[['OPEID6', 'TUITIONFEE_OUT']], how='inner', on='OPEID6').groupby('CONTROL')['TUITIONFEE_OUT'].agg(['min', 'median', 'mean', 'max']).round(2)
# Out:
#                         min   median      mean      max
# CONTROL
# Private, for-profit  8280.0  12233.0  12359.16  25820.0
# Private, nonprofit   4300.0  34245.0  33789.98  61671.0
# Public               3154.0  21312.0  22333.44  47220.0

# %%
institutions_df[['TUITIONFEE_OUT', 'ADM_RATE']].corr()
# Out:
#                 TUITIONFEE_OUT  ADM_RATE
# TUITIONFEE_OUT        1.000000 -0.309658
# ADM_RATE             -0.309658  1.000000

# %%
institutions_df.plot.scatter(x='TUITIONFEE_OUT', y='ADM_RATE', c='MD_EARN_WNE_P10', colormap='Spectral', figsize=(20, 7))
# Out:
# <Axes: xlabel='TUITIONFEE_OUT', ylabel='ADM_RATE'>

# %%
institutions_df['TUITIONFEE_OUT'].describe()
# Out:
# count     3830.000000
# mean     19163.468930
# std      13173.427794
# min        480.000000
# 25%       8927.750000
# 50%      15130.000000
# 75%      25843.000000
# max      61671.000000
# Name: TUITIONFEE_OUT, dtype: float64

# %%
len(institutions_df[(institutions_df['TUITIONFEE_OUT'] > institutions_df['TUITIONFEE_OUT'].quantile(0.75)) & (institutions_df['FTFTPCTPELL'] > institutions_df['FTFTPCTPELL'].quantile(0.75))])
# Out:
# 18

# %%
institutions_df[(institutions_df['TUITIONFEE_OUT'] > institutions_df['TUITIONFEE_OUT'].quantile(0.75)) & (institutions_df['FTFTPCTPELL'] > institutions_df['FTFTPCTPELL'].quantile(0.75))][['INSTNM', 'CITY', 'STABBR']].sort_values('INSTNM')
# Out:
#                                          INSTNM             CITY STABBR
# 5491                            Antioch College   Yellow Springs     OH
# 1206                              Berea College            Berea     KY
# 1930             Berkeley College-Woodland Park    Woodland Park     NJ
# 1932                         Bloomfield College       Bloomfield     NJ
# 2334                          Chowan University     Murfreesboro     NC
# 1543                             Dorsey College  Madison Heights     MI
# 3758                   Dorsey College-Roseville        Roseville     MI
# 5138                     Dorsey College-Saginaw          Saginaw     MI
# 3734                       Dorsey College-Wayne            Wayne     MI
# 1542  Dorsey School of Business-Madison Heights  Madison Heights     MI
# 5718           Felbry College School of Nursing         Columbus     OH
# 4008                  Fortis Institute-Scranton         Scranton     PA
# ...

# %%
institutions_df.loc[(institutions_df['NPT41_PUB'] < 0) | (institutions_df['NPT41_PRIV'] < 0), ['NPT41_PUB', 'NPT41_PRIV']].count()
# Out:
# NPT41_PUB     11
# NPT41_PRIV     1
# dtype: int64

# %%
institutions_df['pub_share'] = institutions_df['NPT41_PUB'] / institutions_df['NPT45_PUB']

# %%
(institutions_df['pub_share'].mean() * 100).round(2)
# Out:
# np.float64(52.33)

# %%
institutions_df['priv_share'] = institutions_df['NPT41_PRIV'] / institutions_df['NPT45_PRIV']

# %%
(institutions_df['priv_share'].mean() * 100).round(2)
# Out:
# np.float64(71.49)

# %%
institutions_df.head()
# Out:
#    OPEID6                               INSTNM        CITY STABBR  ADM_RATE  \
# 0    1002             Alabama A & M University      Normal     AL    0.8965
# 1    1052  University of Alabama at Birmingham  Birmingham     AL    0.8060
# 2   25034                   Amridge University  Montgomery     AL       NaN
# 3    1055  University of Alabama in Huntsville  Huntsville     AL    0.7711
# 4    1005             Alabama State University  Montgomery     AL    0.9888
#
#    NPT4_PUB  NPT4_PRIV  NPT41_PUB  NPT45_PUB  NPT41_PRIV  NPT45_PRIV  \
# 0   15529.0        NaN    14694.0    20483.0         NaN         NaN
# 1   16530.0        NaN    13443.0    19717.0         NaN         NaN
# 2       NaN    17618.0        NaN        NaN     17385.0         NaN
# 3   17208.0        NaN    13631.0    19862.0         NaN         NaN
# 4   19534.0        NaN    19581.0    17559.0         NaN         NaN
#
#    TUITIONFEE_IN  TUITIONFEE_OUT  MD_EARN_WNE_P10  C100_4  FTFTPCTPELL  \
# ...

# %%
institutions_df[(institutions_df['NPT4_PUB'] <= institutions_df['NPT4_PUB'].quantile(0.25)) & (institutions_df['MD_EARN_WNE_P10'] >= institutions_df['MD_EARN_WNE_P10'].quantile(0.75))][['INSTNM', 'CITY', 'STABBR']].sort_values(['STABBR', 'CITY'])
# Out:
#                                            INSTNM           CITY STABBR
# 203   California State University-Dominguez Hills         Carson     CA
# 267                               De Anza College      Cupertino     CA
# 208       California State University-Los Angeles    Los Angeles     CA
# 363                              Moorpark College       Moorpark     CA
# 228                                Canada College   Redwood City     CA
# 450                               Skyline College      San Bruno     CA
# 432                          College of San Mateo      San Mateo     CA
# 652                         University of Florida    Gainesville     FL
# 5563                 University of Florida-Online    Gainesville     FL
# 645              Florida International University          Miami     FL
# 656     George T Baker Aviation Technical College          Miami     FL
# 2013                New Mexico Military Institute        Roswell     NM
# ...

# %%
institutions_df[(institutions_df['NPT4_PUB'] <= institutions_df['NPT4_PUB'].quantile(0.25)) & (institutions_df['MD_EARN_WNE_P10'] >= institutions_df['MD_EARN_WNE_P10'].quantile(0.75))][['INSTNM', 'CITY', 'STABBR']].sort_values(['STABBR', 'CITY']).count()
# Out:
# INSTNM    22
# CITY      22
# STABBR    22
# dtype: int64

# %%
institutions_df[(institutions_df['NPT4_PRIV'] <= institutions_df['NPT4_PRIV'].quantile(0.25)) & (institutions_df['MD_EARN_WNE_P10'] >= institutions_df['MD_EARN_WNE_P10'].quantile(0.75))][['INSTNM', 'CITY', 'STABBR']].sort_values(['STABBR', 'CITY'])
# Out:
#                                                  INSTNM              CITY  \
# 4795                       Columbia Southern University      Orange Beach
# 3695                                Stanford University          Stanford
# 4208  Mercy Hospital School of Practical Nursing-Pla...             Miami
# 842                      Brigham Young University-Idaho           Rexburg
# 895                   Graham Hospital School of Nursing            Canton
# 978                             Saint Xavier University           Chicago
# 1011                    Calumet College of Saint Joseph           Whiting
# 1297                           University of Holy Cross       New Orleans
# 1448                                 Harvard University         Cambridge
# 1383                      Ner Israel Rabbinical College         Baltimore
# 1775                                   Logan University      Chesterfield
# 1877                              College of Saint Mary             Omaha
# ...

# %%
institutions_df[(institutions_df['NPT4_PRIV'] <= institutions_df['NPT4_PRIV'].quantile(0.25)) & (institutions_df['MD_EARN_WNE_P10'] >= institutions_df['MD_EARN_WNE_P10'].quantile(0.75))][['INSTNM', 'CITY', 'STABBR']].sort_values(['STABBR', 'CITY']).count()
# Out:
# INSTNM    30
# CITY      30
# STABBR    30
# dtype: int64

# %%
institutions_df[['ADM_RATE', 'C100_4']].corr()
# Out:
#           ADM_RATE    C100_4
# ADM_RATE  1.000000 -0.336871
# C100_4   -0.336871  1.000000

# %%
pd.merge(left=institutions_df[['OPEID6', 'MD_EARN_WNE_P10']],right=fields_of_study_df[['OPEID6', 'CONTROL']].groupby('OPEID6')['CONTROL'].min(), how='inner', on='OPEID6').groupby('CONTROL')['MD_EARN_WNE_P10'].mean().sort_values(ascending=False).round(2)
# Out:
# CONTROL
# Private, nonprofit     48530.41
# Public                 40314.44
# Private, for-profit    30474.75
# Name: MD_EARN_WNE_P10, dtype: float64

# %%
league = [
    'Harvard University',
    'Massachusetts Institute of Technology',
    'Yale University',
    'Columbia University in the City of New York',
    'Brown University',
    'Stanford University',
    'University of Chicago',
    'Dartmouth College',
    'University of Pennsylvania',
    'Cornell University',
    'Princeton University'
]

# %%
institutions_df.loc[institutions_df['INSTNM'].isin(league), 'MD_EARN_WNE_P10'].mean()
# Out:
# np.float64(91806.81818181818)

# %%
institutions_df.groupby('STABBR', observed=True)['MD_EARN_WNE_P10'].mean().sort_values(ascending=False).round(2)
# Out:
# STABBR
# MA    53234.40
# RI    50432.79
# DC    49081.47
# CT    48662.02
# VT    48383.86
# NY    47584.65
# NH    46540.79
# WA    44594.68
# PA    44265.73
# MN    43821.51
# MD    42875.72
# NJ    42797.20
# CA    42634.26
# AK    42270.71
# NE    41762.11
# HI    41685.00
# WI    41674.01
# VA    40912.41
# NV    40906.82
# IN    40777.91
# DE    40764.23
# IL    40686.66
# ME    40152.71
# OR    40122.29
# KS    39788.31
# IA    39753.28
# MO    39730.02
# CO    39542.41
# ND    39095.14
# SD    38882.43
# OH    38781.42
# UT    37965.85
# VI    37808.00
# GA    37158.14
# WY    36911.70
# TX    36634.61
# AL    36591.56
# AZ    36405.66
# MI    36394.24
# NC    35727.82
# FL    35490.41
# TN    35184.23
# SC    35074.63
# NM    34865.47
# MT    34436.78
# WV    34304.63
# OK    33970.27
# KY    33943.36
# LA    32442.83
# ID    32142.44
# MS    31300.12
# AR    31120.35
# MH    29192.00
# AS    27265.00
# GU    26182.33
# MP    24972.00
# FM    22919.00
# PR    21613.22
# ...

# %%
institutions_df.groupby('STABBR', observed=True)['MD_EARN_WNE_P10'].mean().dropna().sort_values().plot.bar(figsize=(15, 7))
# Out:
# <Axes: xlabel='STABBR'>

# %%
institutions_df.groupby('STABBR', observed=True)['MD_EARN_WNE_P10'].mean().dropna().sort_values().plot.box()
# Out:
# <Axes: >
