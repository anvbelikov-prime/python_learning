# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/nyc-parking-violations-2020.csv', usecols=['Plate ID', 'Registration State', 'Vehicle Make', 'Vehicle Color', 'Violation Time', 'Street Name'])
df
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
len(df)
# Out:
# 12495734

# %%
df.shape
# Out:
# (12495734, 6)

# %%
df1 = df.dropna().copy()
df1
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 4          FMY9090                 NY         JEEP          1253A
# 5          KDG0693                 PA         HYUN          0525P
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
len(df1)
# Out:
# 12048375

# %%
len(df) - len(df1)
# Out:
# 447359

# %%
(len(df) - len(df1)) * 100
# Out:
# 44735900

# %%
df2 = df.dropna(subset=['Plate ID', 'Registration State', 'Vehicle Make', 'Street Name']).copy()
df2
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
len(df2)
# Out:
# 12431949

# %%
len(df) - len(df2)
# Out:
# 63785

# %%
(len(df) - len(df2)) * 100
# Out:
# 6378500

# %%
df3 = df.dropna(subset=['Plate ID', 'Registration State', 'Street Name']).copy()
df3
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
len(df) - len(df3)
# Out:
# 1618

# %%
(len(df) - len(df3)) * 100
# Out:
# 161800

# %%
# 25.1

# %%
df4 = df.dropna(subset=['Plate ID', 'Registration State', 'Vehicle Make', 'Street Name'], thresh=3).copy()
df4
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
len(df4)
# Out:
# 12495481

# %%
len(df) - len(df4)
# Out:
# 253

# %%
# 25.2

# %%
(len(df) - df.count()).sort_values(ascending=False)
# Out:
# Vehicle Color         391982
# Vehicle Make           62420
# Street Name             1417
# Violation Time           278
# Plate ID                 202
# Registration State         0
# dtype: int64

# %%
# 25.3

# %%
df.mode()
# Out:
#      Plate ID Registration State Vehicle Make Violation Time Street Name  \
# 0  BLANKPLATE                 NY        TOYOT          0836A    Broadway
#
#   Vehicle Color
# 0            WH

# %%
df.loc[df['Plate ID'] == 'BLANKPLATE', 'Plate ID'] = np.nan

# %%
(len(df) - df.count()).sort_values(ascending=False)
# Out:
# Vehicle Color         391982
# Vehicle Make           62420
# Plate ID                9084
# Street Name             1417
# Violation Time           278
# Registration State         0
# dtype: int64

# %%
df5 = df.dropna(subset=['Plate ID', 'Registration State', 'Vehicle Make', 'Street Name'], thresh=3).copy()
df5
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
len(df) - len(df5)
# Out:
# 944
