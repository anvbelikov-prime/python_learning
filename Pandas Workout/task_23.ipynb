# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/olympic_athlete_events.csv', usecols=['Age', 'Height', 'Team', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'], index_col=['Year', 'Season', 'Sport', 'Event'])
df = df.sort_index()
df
# Out:
#                                                                   Age  Height  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres               24.0     NaN
#                       Athletics Men's 1,500 metres                NaN     NaN
#                       Athletics Men's 1,500 metres               22.0     NaN
#                       Athletics Men's 1,500 metres               23.0   154.0
#                       Athletics Men's 1,500 metres               21.0     NaN
# ...                                                               ...     ...
# 2016 Summer Wrestling Wrestling Women's Middleweight, Freestyle  33.0   161.0
#                       Wrestling Women's Middleweight, Freestyle  26.0   170.0
#                       Wrestling Women's Middleweight, Freestyle  25.0   170.0
#                       Wrestling Women's Middleweight, Freestyle  21.0   170.0
#                       Wrestling Women's Middleweight, Freestyle  25.0   163.0
#
# ...

# %%
df.index.is_monotonic_increasing
# Out:
# True

# %%
df.index.is_monotonic_decreasing
# Out:
# False

# %%
df.loc[(slice(1936, 2000), 'Summer'), ['Medal', 'Age']].query('Medal == "Gold"')['Age'].mean()
# Out:
# np.float64(25.1371932032725)

# %%
df.loc[(slice(1936, 2000), 'Summer'), ['Age']].mean()
# Out:
# Age    25.026884
# dtype: float64

# %%
df.loc[(slice(None), slice(None), 'Archery'), ['Medal', 'Team']].query('Medal.notnull()')['Team'].value_counts().head(1)
# Out:
# Team
# South Korea    69
# Name: count, dtype: int64

# %%
df.loc[(slice(1980, None), slice(None), slice(None), "Table Tennis Women's Team"), 'Height'].mean()
# Out:
# np.float64(165.04827586206898)

# %%
df.loc[(slice(1980, None), slice(None), slice(None), ["Table Tennis Women's Team", "Table Tennis Men's Team"]), 'Height'].mean()
# Out:
# np.float64(171.26643598615917)

# %%
df.loc[(slice(1980, 2016), slice(None), 'Tennis'), 'Height'].max()
# Out:
# 208.0

# %%
# 23.1

# %%
df1 = df.copy()

# %%
df1 = df1.reset_index().set_index(keys=['Year', 'Sport', 'Event']).sort_index()
df1
# Out:
#                                                           Season   Age  \
# Year Sport     Event
# 1896 Athletics Athletics Men's 1,500 metres               Summer  24.0
#                Athletics Men's 1,500 metres               Summer   NaN
#                Athletics Men's 1,500 metres               Summer  22.0
#                Athletics Men's 1,500 metres               Summer  23.0
#                Athletics Men's 1,500 metres               Summer  21.0
# ...                                                          ...   ...
# 2016 Wrestling Wrestling Women's Middleweight, Freestyle  Summer  33.0
#                Wrestling Women's Middleweight, Freestyle  Summer  26.0
#                Wrestling Women's Middleweight, Freestyle  Summer  25.0
#                Wrestling Women's Middleweight, Freestyle  Summer  21.0
#                Wrestling Women's Middleweight, Freestyle  Summer  25.0
#
#                                                           Height  \
# Year Sport     Event
# ...

# %%
df1.loc[(slice(1980, 2016), 'Tennis'), 'Height'].max()
# Out:
# 208.0

# %%
# 23.2

# %%
df.head()
# Out:
#                                                      Age  Height  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres  24.0     NaN
#                       Athletics Men's 1,500 metres   NaN     NaN
#                       Athletics Men's 1,500 metres  22.0     NaN
#                       Athletics Men's 1,500 metres  23.0   154.0
#                       Athletics Men's 1,500 metres  21.0     NaN
#
#                                                              Team    City  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres  United States  Athina
#                       Athletics Men's 1,500 metres         Greece  Athina
#                       Athletics Men's 1,500 metres      Australia  Athina
#                       Athletics Men's 1,500 metres        Germany  Athina
#                       Athletics Men's 1,500 metres         Greece  Athina
#
#                                                      Medal
# ...

# %%
df.loc[(slice(1980, None)), ('Medal', 'City')].query('Medal == "Gold"')['City'].value_counts().head(1)
# Out:
# City
# Beijing    671
# Name: count, dtype: int64

# %%
# 23.3

# %%
df.head()
# Out:
#                                                      Age  Height  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres  24.0     NaN
#                       Athletics Men's 1,500 metres   NaN     NaN
#                       Athletics Men's 1,500 metres  22.0     NaN
#                       Athletics Men's 1,500 metres  23.0   154.0
#                       Athletics Men's 1,500 metres  21.0     NaN
#
#                                                              Team    City  \
# Year Season Sport     Event
# 1896 Summer Athletics Athletics Men's 1,500 metres  United States  Athina
#                       Athletics Men's 1,500 metres         Greece  Athina
#                       Athletics Men's 1,500 metres      Australia  Athina
#                       Athletics Men's 1,500 metres        Germany  Athina
#                       Athletics Men's 1,500 metres         Greece  Athina
#
#                                                      Medal
# ...

# %%
df.loc[(slice(1980, None)), ['Medal', 'Team']].query('(Medal == "Gold") & (Team == "United States")').count()
# Out:
# Medal    1257
# Team     1257
# dtype: int64
