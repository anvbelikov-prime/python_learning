# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(
    'data/sat-scores.csv',
    usecols=['Year', 'State.Code', 'Total.Math', 'Total.Test-takers', 'Total.Verbal']
)
df
# Out:
#      Year State.Code  Total.Math  Total.Test-takers  Total.Verbal
# 0    2005         AL         559               3985           567
# 1    2005         AK         519               3996           523
# 2    2005         AZ         530              18184           526
# 3    2005         AR         552               1600           563
# 4    2005         CA         522             186552           504
# ..    ...        ...         ...                ...           ...
# 572  2015         VA         517              59621           518
# 573  2015         WA         511              44423           502
# 574  2015         WV         500               2501           509
# 575  2015         WI         606               2277           591
# 576  2015         WY         587                181           588
#
# [577 rows x 5 columns]

# %%
df = df.set_index(keys=['Year', 'State.Code']).sort_index()
df
# Out:
#                  Total.Math  Total.Test-takers  Total.Verbal
# Year State.Code
# 2005 AK                 519               3996           523
#      AL                 559               3985           567
#      AR                 552               1600           563
#      AZ                 530              18184           526
#      CA                 522             186552           504
# ...                     ...                ...           ...
# 2015 VT                 524               4564           522
#      WA                 511              44423           502
#      WI                 606               2277           591
#      WV                 500               2501           509
#      WY                 587                181           588
#
# [577 rows x 3 columns]

# %%
df.loc[(2005,), 'Total.Test-takers'].sum()
# Out:
# np.int64(1344824)

# %%
df.loc[(2010, ['NY', 'NJ', 'MA', 'IL']), 'Total.Math'].mean()
# Out:
# np.float64(535.25)

# %%
df.loc[(slice(2012, 2015), ['AZ', 'CA', 'TX']), 'Total.Verbal'].mean()
# Out:
# np.float64(497.3333333333333)

# %%
# 22.1

# %%
df.loc[(slice(None), ['FL', 'IN', 'ID']), ['Total.Math', 'Total.Verbal']].mean()
# Out:
# Total.Math      507.090909
# Total.Verbal    504.606061
# dtype: float64

# %%
# 22.2

# %%
df['Total.Verbal'].idxmax()
# Out:
# (np.int64(2013), 'ND')

# %%
# 22.3

# %%
df.loc[(2005), 'Total.Math'].mean()
# Out:
# np.float64(535.6538461538462)

# %%
df.loc[(2015), 'Total.Math'].mean()
# Out:
# np.float64(533.0943396226415)

# %%
df.loc[(2005), 'Total.Math'].mean() - df.loc[(2015), 'Total.Math'].mean()
# Out:
# np.float64(2.559506531204647)
