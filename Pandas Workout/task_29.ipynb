# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/nyc_taxi_2019-01.csv', usecols=['passenger_count', 'trip_distance', 'total_amount'])
df
# Out:
#          passenger_count  trip_distance  total_amount
# 0                      1           1.50          9.95
# 1                      1           2.60         16.30
# 2                      3           0.00          5.80
# 3                      5           0.00          7.55
# 4                      5           0.00         55.55
# ...                  ...            ...           ...
# 7667787                1           4.79         23.16
# 7667788                1           0.00          0.00
# 7667789                1           0.00          0.00
# 7667790                1           0.00          0.00
# 7667791                1           0.00          0.00
#
# [7667792 rows x 3 columns]

# %%
len(df) - df.count()
# Out:
# passenger_count    0
# trip_distance      0
# total_amount       0
# dtype: int64

# %%
df.sort_values(by=['trip_distance'], ascending=[False]).iloc[:20]['total_amount'].mean().round(2)
# Out:
# np.float64(290.01)

# %%
df.sort_values(by=['trip_distance'], ascending=[True]).iloc[-20:]['total_amount'].mean().round(2)
# Out:
# np.float64(290.01)

# %%
df.sort_values(by=['trip_distance'], ascending=[True]).tail(20)['total_amount'].mean().round(2)
# Out:
# np.float64(290.01)

# %%
df.sort_values(by=['passenger_count', 'trip_distance'], ascending=[True, False]).head(50)['total_amount'].mean()
# Out:
# np.float64(135.49739999999997)

# %%
df.sort_values(by=['passenger_count', 'trip_distance'], ascending=[True, False]).head(50)['total_amount'].mean().round(2)
# Out:
# np.float64(135.5)

# %%
# 29.1

# %%
df.head()
# Out:
#    passenger_count  trip_distance  total_amount
# 0                1            1.5          9.95
# 1                1            2.6         16.30
# 2                3            0.0          5.80
# 3                5            0.0          7.55
# 4                5            0.0         55.55

# %%
df['amount_per_mile'] = df['total_amount'] / df['trip_distance']

# %%
df.head()
# Out:
#    passenger_count  trip_distance  total_amount  amount_per_mile
# 0                1            1.5          9.95         6.633333
# 1                1            2.6         16.30         6.269231
# 2                3            0.0          5.80              inf
# 3                5            0.0          7.55              inf
# 4                5            0.0         55.55              inf

# %%
df.loc[df['trip_distance'] != 0.0].sort_values(by=['amount_per_mile'], ascending=[False]).iloc[:5]['trip_distance']
# Out:
# 2499600    2.40
# 478791     0.10
# 7099014    0.01
# 6403254    0.01
# 4136499    0.01
# Name: trip_distance, dtype: float64

# %%
# 29.2

# %%
df['amount_per_passenger'] = df['total_amount'] / df['passenger_count']

# %%
df.head()
# Out:
#    passenger_count  trip_distance  total_amount  amount_per_mile  \
# 0                1            1.5          9.95         6.633333
# 1                1            2.6         16.30         6.269231
# 2                3            0.0          5.80              inf
# 3                5            0.0          7.55              inf
# 4                5            0.0         55.55              inf
#
#    amount_per_passenger
# 0              9.950000
# 1             16.300000
# 2              1.933333
# 3              1.510000
# 4             11.110000

# %%
df.loc[df['passenger_count'] > 1].sort_values(by=['amount_per_passenger'], ascending=[False]).head(10)
# Out:
#          passenger_count  trip_distance  total_amount  amount_per_mile  \
# 2972145                2          19.90        589.96        29.646231
# 3014027                2          16.60        560.76        33.780723
# 3842620                2         110.04        515.82         4.687568
# 7593395                2          83.61        449.32         5.373998
# 149362                 2          17.20        426.80        24.813953
# 5726185                2          65.05        416.82         6.407686
# 6857368                2           0.00        411.36              inf
# 6496403                2           0.00        410.95              inf
# 4751745                2         100.78        403.50         4.003771
# 1154626                2           0.00        400.80              inf
#
#          amount_per_passenger
# 2972145               294.980
# 3014027               280.380
# 3842620               257.910
# 7593395               224.660
# 149362                213.400
# ...

# %%
# 29.3

# %%
df.sort_values(by=['trip_distance'], ascending=[False], ignore_index=True)['total_amount'].loc[:19].mean().round(2)
# Out:
# np.float64(290.01)

# %%
df.sort_values(by=['trip_distance'], ascending=[False]).iloc[:20]['total_amount'].mean().round(2)
# Out:
# np.float64(290.01)
