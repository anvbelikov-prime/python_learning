# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(
        'data/nyc-parking-violations-2020.csv',
        usecols=['Date First Observed', 'Plate ID', 'Registration State', 'Issue Date', 'Vehicle Make', 'Street Name', 'Vehicle Color'],
        parse_dates=['Issue Date']
)
df
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_1482/3746654222.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(
#           Plate ID Registration State Issue Date Vehicle Make  \
# 0           J58JKX                 NJ 1972-05-08        HONDA
# 1          KRE6058                 PA 1977-08-29        ME/BE
# 2          444326R                 NJ 1988-10-03        LEXUS
# 3          F728330                 OH 1990-01-03        CHEVR
# 4          FMY9090                 NY 1990-02-14         JEEP
# ...            ...                ...        ...          ...
# 12495729   62161MM                 NY 2040-01-03         FORD
# 12495730   GYE7330                 NY 2045-04-19        HONDA
# 12495731   HNY4802                 NY 2049-01-17         FORD
# 12495732  T687081C                 NY 2063-12-19        TOYOT
# ...

# %%
df = df.set_index(keys=['Issue Date'])

# %%
df
# Out:
#             Plate ID Registration State Vehicle Make       Street Name  \
# Issue Date
# 1972-05-08    J58JKX                 NJ        HONDA             43 ST
# 1977-08-29   KRE6058                 PA        ME/BE          UNION ST
# 1988-10-03   444326R                 NJ        LEXUS   CLERMONT AVENUE
# 1990-01-03   F728330                 OH        CHEVR      DIVISION AVE
# 1990-02-14   FMY9090                 NY         JEEP          GRAND ST
# ...              ...                ...          ...               ...
# 2040-01-03   62161MM                 NY         FORD           3RD AVE
# 2045-04-19   GYE7330                 NY        HONDA    PELHAM PARK DR
# 2049-01-17   HNY4802                 NY         FORD         LYDIG AVE
# 2063-12-19  T687081C                 NY        TOYOT       E 68 STREET
# 2064-06-04    3497ZN                 WA        UTILI  W/S/O 182 STREET
#
#             Date First Observed Vehicle Color
# Issue Date
# ...

# %%
df.loc[('2020-01-02',), 'Vehicle Make'].value_counts().iloc[:3]
# Out:
# Vehicle Make
# TOYOT    3829
# HONDA    3593
# FORD     3164
# Name: count, dtype: int64

# %%
df.loc[('2020-06-01',), 'Street Name'].value_counts().iloc[:5]
# Out:
# Street Name
# WB CONDUIT BLVD @ LI    1068
# SB WEST ST @ LEROY S     335
# EB HORACE HARDING EX     273
# EB QUEENS BLVD @ 82N     245
# WB ATLANTIC AVE @ CL     229
# Name: count, dtype: int64

# %%
df = df.reset_index()

# %%
df = df.set_index(keys=['Vehicle Color'])

# %%
df
# Out:
#               Issue Date  Plate ID Registration State Vehicle Make  \
# Vehicle Color
# BK            1972-05-08    J58JKX                 NJ        HONDA
# BLK           1977-08-29   KRE6058                 PA        ME/BE
# BLACK         1988-10-03   444326R                 NJ        LEXUS
# NaN           1990-01-03   F728330                 OH        CHEVR
# GREY          1990-02-14   FMY9090                 NY         JEEP
# ...                  ...       ...                ...          ...
# BR            2040-01-03   62161MM                 NY         FORD
# BLK           2045-04-19   GYE7330                 NY        HONDA
# GY            2049-01-17   HNY4802                 NY         FORD
# BLK           2063-12-19  T687081C                 NY        TOYOT
# WHITE         2064-06-04    3497ZN                 WA        UTILI
#
#                     Street Name  Date First Observed
# Vehicle Color
# BK                        43 ST                    0
# ...

# %%
df.index.unique()
# Out:
# Index([   'BK',   'BLK', 'BLACK',     nan,  'GREY',    'GY',    'WH',   'RED',
#         'GRAY',   'TAN',
#        ...
#        'GYHNU',   'BLF',   'BL9', 'LTBR0',   'BK;', 'GLKPP',    '';', 'WHGY8',
#         'ORYW',    'CH'],
#       dtype='object', name='Vehicle Color', length=1897)

# %%
df.loc[[('BLUE'), ('RED')], ('Vehicle Make')].value_counts().iloc[:1]
# Out:
# Vehicle Make
# HONDA    39353
# Name: count, dtype: int64

# %%
# 21.1

# %%
df = df.reset_index().set_index(keys=['Issue Date']).sort_index()

# %%
df
# Out:
#            Vehicle Color  Plate ID Registration State Vehicle Make  \
# Issue Date
# 1972-05-08            BK    J58JKX                 NJ        HONDA
# 1977-08-29           BLK   KRE6058                 PA        ME/BE
# 1988-10-03         BLACK   444326R                 NJ        LEXUS
# 1990-01-03           NaN   F728330                 OH        CHEVR
# 1990-02-14          GREY   FMY9090                 NY         JEEP
# ...                  ...       ...                ...          ...
# 2040-01-03            BR   62161MM                 NY         FORD
# 2045-04-19           BLK   GYE7330                 NY        HONDA
# 2049-01-17            GY   HNY4802                 NY         FORD
# 2063-12-19           BLK  T687081C                 NY        TOYOT
# 2064-06-04         WHITE    3497ZN                 WA        UTILI
#
#                  Street Name  Date First Observed
# Issue Date
# 1972-05-08             43 ST                    0
# ...

# %%
df.loc[('2020-01-02'):('2020-01-10'), 'Vehicle Make'].value_counts()
# Out:
# Vehicle Make
# FORD     38936
# TOYOT    37073
# HONDA    35944
# NISSA    29573
# CHEVR    20004
#          ...
# FOUR         1
# I NFI        1
# ZENGH        1
# WPRK         1
# STUDE        1
# Name: count, Length: 574, dtype: int64

# %%
# 21.2

# %%
df.head()
# Out:
#            Vehicle Color Plate ID Registration State Vehicle Make  \
# Issue Date
# 1972-05-08            BK   J58JKX                 NJ        HONDA
# 1977-08-29           BLK  KRE6058                 PA        ME/BE
# 1988-10-03         BLACK  444326R                 NJ        LEXUS
# 1990-01-03           NaN  F728330                 OH        CHEVR
# 1990-02-14          GREY  FMY9090                 NY         JEEP
#
#                 Street Name  Date First Observed
# Issue Date
# 1972-05-08            43 ST                    0
# 1977-08-29         UNION ST                    0
# 1988-10-03  CLERMONT AVENUE                    0
# 1990-01-03     DIVISION AVE                    0
# 1990-02-14         GRAND ST                    0

# %%
df['Plate ID'].value_counts()
# Out:
# Plate ID
# BLANKPLATE    8882
# 2704819       1535
# 86107MM       1429
# 2703289       1364
# NS            1189
#               ...
# 0ASBR8           1
# GSG6485          1
# HAS7271          1
# BATMAN01         1
# T64528C          1
# Name: count, Length: 3245467, dtype: int64

# %%
df = df.reset_index().set_index(keys=['Plate ID']).sort_index()
df
# Out:
#          Issue Date Vehicle Color Registration State Vehicle Make  \
# Plate ID
# 000000   2020-02-19         BLACK                 PA        CADIL
# 000000   2019-08-09         BLACK                 PA        CADIL
# 000000   2019-11-22         BLACK                 PA        NS/OT
# 00000K   2020-02-15         BLACK                 VA          BMW
# 00004    2019-08-31         SILVE                 PA        HONDA
# ...             ...           ...                ...          ...
# NaN      2020-04-18          GREY                 NY        NISSA
# NaN      2020-04-18          GREY                 NY        NISSA
# NaN      2020-04-18          GREY                 NY        NISSA
# NaN      2020-05-16         BLACK                 NJ        ME/BE
# NaN      2020-06-11           NaN                 NY          NaN
#
#                   Street Name  Date First Observed
# Plate ID
# 000000                60th St                    0
# ...

# %%
df.loc['2704819', 'Registration State'].value_counts()
# Out:
# Registration State
# IN    1527
# NJ       5
# NY       2
# ME       1
# Name: count, dtype: int64

# %%
# 21.3

# %%
df['Date First Observed'].unique()
# Out:
# array([       0, 20190727, 20191113, 20200211, 20190701, 20190808,
#        20190703, 20190708, 20190709, 20190910, 20190723, 20200310,
#        20200115, 20191202, 20200219, 20190705, 20191107, 20191015,
#        20191005, 20190628, 20191122, 20190810, 20191210, 20200104,
#        20190818, 20190710, 20190819, 20200226, 20200311, 20190911,
#        20191121, 20190904, 20191207, 20191125, 20191112, 20190626,
#        20190815, 20200127, 20190909, 20190724, 20190627, 20191030,
#        20200527, 20200608, 20200207, 20200220, 20200122, 20191007,
#        20190903, 20190802, 20191012, 20191216, 20190715, 20190717,
#        20190913, 20191011, 20190817, 20190826, 20200223, 20200312,
#        20191105, 20191004, 20200130, 20190902, 20190930, 20190718,
#        20200228, 20200117, 20200124, 20200213, 20200121, 20200206,
#        20200221, 20190916, 20200305, 20191213, 20191230, 20191203,
#        20190814, 20200609, 20190816, 20190830, 20190726, 20200128,
# ...

# %%
df['Date First Observed'].nunique()
# Out:
# 465

# %%
len(df)
# Out:
# 12495734

# %%
df['Issue Date'].nunique()
# Out:
# 1475
