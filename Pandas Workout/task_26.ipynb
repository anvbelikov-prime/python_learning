# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(
    'data/celebrity_deaths_2016.csv',
    usecols=['dateofdeath', 'age'],
)
df
# Out:
#      dateofdeath age
# 0     2016-01-01  71
# 1     2016-01-01  74
# 2     2016-01-01  79
# 3     2016-01-01  45
# 4     2016-01-01  83
# ...          ...  ..
# 6538  2016-12-27  74
# 6539  2016-12-27  85
# 6540  2016-12-27  83
# 6541  2016-12-27  23
# 6542  2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
df.dtypes
# Out:
# dateofdeath    object
# age            object
# dtype: object

# %%
df['month'] = df['dateofdeath'].str.split('-').str.get(1).astype(np.int8)

# %%
df
# Out:
#      dateofdeath age  month
# 0     2016-01-01  71      1
# 1     2016-01-01  74      1
# 2     2016-01-01  79      1
# 3     2016-01-01  45      1
# 4     2016-01-01  83      1
# ...          ...  ..    ...
# 6538  2016-12-27  74     12
# 6539  2016-12-27  85     12
# 6540  2016-12-27  83     12
# 6541  2016-12-27  23     12
# 6542  2016-12-27  84     12
#
# [6543 rows x 3 columns]

# %%
df = df.set_index(keys=['month'])
df
# Out:
#       dateofdeath age
# month
# 1      2016-01-01  71
# 1      2016-01-01  74
# 1      2016-01-01  79
# 1      2016-01-01  45
# 1      2016-01-01  83
# ...           ...  ..
# 12     2016-12-27  74
# 12     2016-12-27  85
# 12     2016-12-27  83
# 12     2016-12-27  23
# 12     2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
df = df.sort_index()

# %%
df
# Out:
#       dateofdeath age
# month
# 1      2016-01-01  71
# 1      2016-01-21  47
# 1      2016-01-21  87
# 1      2016-01-21  90
# 1      2016-01-21  73
# ...           ...  ..
# 12     2016-12-10  63
# 12     2016-12-10  20
# 12     2016-12-10  57
# 12     2016-12-10  78
# 12     2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
df['age'].value_counts()
# Out:
# age
# 88       236
# 86       236
# 85       225
# 87       225
# 90       223
#         ...
#  9192      1
# 110        1
# 116        1
#  7374      1
#  2930      1
# Name: count, Length: 138, dtype: int64

# %%
df['age'].str.isdigit().astype(np.bool)
# Out:
# month
# 1     True
# 1     True
# 1     True
# 1     True
# 1     True
#       ...
# 12    True
# 12    True
# 12    True
# 12    True
# 12    True
# Name: age, Length: 6543, dtype: bool

# %%
df.loc[~(df['age'].str.isdigit().astype(np.bool)), 'age'] = np.nan

# %%
df.head()
# Out:
#       dateofdeath age
# month
# 1      2016-01-01  71
# 1      2016-01-21  47
# 1      2016-01-21  87
# 1      2016-01-21  90
# 1      2016-01-21  73

# %%
df['age'].value_counts()
# Out:
# age
# 86     236
# 88     236
# 85     225
# 87     225
# 90     223
#       ...
# 116      1
# 112      1
# 18       1
# 12       1
# 7        1
# Name: count, Length: 104, dtype: int64

# %%
df['age'].describe()
# Out:
# count     6481
# unique     104
# top         86
# freq       236
# Name: age, dtype: object

# %%
df['age'] = df['age'].astype(np.int8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['age'] = df['age'].astype(np.int8)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df = df.dropna(subset=['age']).copy()

# %%
df['age'] = df['age'].astype(np.int8)

# %%
df
# Out:
#       dateofdeath  age
# month
# 1      2016-01-01   71
# 1      2016-01-21   47
# 1      2016-01-21   87
# 1      2016-01-21   90
# 1      2016-01-21   73
# ...           ...  ...
# 12     2016-12-10   63
# 12     2016-12-10   20
# 12     2016-12-10   57
# 12     2016-12-10   78
# 12     2016-12-27   84
#
# [6481 rows x 2 columns]

# %%
df.loc[2:7, 'age'].mean()
# Out:
# np.float64(77.17887409200968)

# %%
# 26.1

# %%
df = pd.read_csv(
    'data/celebrity_deaths_2016.csv',
    usecols=['dateofdeath', 'age'],
)
df
# Out:
#      dateofdeath age
# 0     2016-01-01  71
# 1     2016-01-01  74
# 2     2016-01-01  79
# 3     2016-01-01  45
# 4     2016-01-01  83
# ...          ...  ..
# 6538  2016-12-27  74
# 6539  2016-12-27  85
# 6540  2016-12-27  83
# 6541  2016-12-27  23
# 6542  2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
df[['year', 'month', 'day']] = df['dateofdeath'].str.split('-', expand=True)

# %%
df
# Out:
#      dateofdeath age  year month day
# 0     2016-01-01  71  2016    01  01
# 1     2016-01-01  74  2016    01  01
# 2     2016-01-01  79  2016    01  01
# 3     2016-01-01  45  2016    01  01
# 4     2016-01-01  83  2016    01  01
# ...          ...  ..   ...   ...  ..
# 6538  2016-12-27  74  2016    12  27
# 6539  2016-12-27  85  2016    12  27
# 6540  2016-12-27  83  2016    12  27
# 6541  2016-12-27  23  2016    12  27
# 6542  2016-12-27  84  2016    12  27
#
# [6543 rows x 5 columns]

# %%
len(df) - df.count()
# Out:
# dateofdeath     0
# age            27
# year            0
# month           0
# day             0
# dtype: int64

# %%
df = df.set_index(keys=['month', 'day']).sort_index()
df
# Out:
#           dateofdeath age  year
# month day
# 01    01   2016-01-01  71  2016
#       01   2016-01-01  74  2016
#       01   2016-01-01  79  2016
#       01   2016-01-01  45  2016
#       01   2016-01-01  83  2016
# ...               ...  ..   ...
# 12    29   2016-12-29  83  2016
#       29   2016-12-29  88  2016
#       29   2016-12-29  88  2016
#       29   2016-12-29  89  2016
#       29   2016-12-29  53  2016
#
# [6543 rows x 3 columns]

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df
# Out:
#           dateofdeath   age  year
# month day
# 01    01   2016-01-01  71.0  2016
#       01   2016-01-01  74.0  2016
#       01   2016-01-01  79.0  2016
#       01   2016-01-01  45.0  2016
#       01   2016-01-01  83.0  2016
# ...               ...   ...   ...
# 12    29   2016-12-29  83.0  2016
#       29   2016-12-29  88.0  2016
#       29   2016-12-29  88.0  2016
#       29   2016-12-29  89.0  2016
#       29   2016-12-29  53.0  2016
#
# [6543 rows x 3 columns]

# %%
len(df) - df.count()
# Out:
# dateofdeath     0
# age            38
# year            0
# dtype: int64

# %%
df1 = df.loc[df['age'] < 120]
df1
# Out:
#           dateofdeath   age  year
# month day
# 01    01   2016-01-01  71.0  2016
#       01   2016-01-01  74.0  2016
#       01   2016-01-01  79.0  2016
#       01   2016-01-01  45.0  2016
#       01   2016-01-01  83.0  2016
# ...               ...   ...   ...
# 12    29   2016-12-29  83.0  2016
#       29   2016-12-29  88.0  2016
#       29   2016-12-29  88.0  2016
#       29   2016-12-29  89.0  2016
#       29   2016-12-29  53.0  2016
#
# [6481 rows x 3 columns]

# %%
df1.loc[('02', '15'):('07', '15'), 'age'].mean()
# Out:
# np.float64(77.05183037332367)

# %%
# 26.2

# %%
df = pd.read_csv(
    'data/celebrity_deaths_2016.csv',
    usecols=['dateofdeath', 'age', 'causeofdeath'],
)
df
# Out:
#      dateofdeath age                causeofdeath
# 0     2016-01-01  71                brain cancer
# 1     2016-01-01  74                      cancer
# 2     2016-01-01  79                      cancer
# 3     2016-01-01  45   complications of a stroke
# 4     2016-01-01  83               heart failure
# ...          ...  ..                         ...
# 6538  2016-12-27  74                         NaN
# 6539  2016-12-27  85                         NaN
# 6540  2016-12-27  83                         NaN
# 6541  2016-12-27  23                  euthanized
# 6542  2016-12-27  84                         NaN
#
# [6543 rows x 3 columns]

# %%
df['causeofdeath'].value_counts()
# Out:
# causeofdeath
#  cancer                                                248
#  heart attack                                          125
#  traffic collision                                      56
#  lung cancer                                            51
#  pneumonia                                              50
#                                                       ...
#  complications from accident                             1
#  septic shock                                            1
#  grenade explosion                                       1
#  complications from esophageal cancer and pneumonia      1
# euthanized                                               1
# Name: count, Length: 361, dtype: int64

# %%
len(df) - df.count()
# Out:
# dateofdeath        0
# age               27
# causeofdeath    5008
# dtype: int64

# %%
df.loc[df['causeofdeath'].isnull(), 'causeofdeath'] = 'unknown'

# %%
df['causeofdeath'].value_counts()
# Out:
# causeofdeath
# unknown                                                5008
#  cancer                                                 248
#  heart attack                                           125
#  traffic collision                                       56
#  lung cancer                                             51
#                                                        ...
#  complications from accident                              1
#  septic shock                                             1
#  grenade explosion                                        1
#  complications from esophageal cancer and pneumonia       1
# euthanized                                                1
# Name: count, Length: 362, dtype: int64

# %%
# 26.3

# %%
df.loc[df['causeofdeath'].str.contains('cancer'), 'causeofdeath'].value_counts().sum()
# Out:
# np.int64(529)
