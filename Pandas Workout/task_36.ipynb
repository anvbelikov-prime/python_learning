# %%
import numpy as np
import pandas as pd

# %%
data_words = []
with open('data/alice-in-wonderland.txt', 'r') as f:
    for line in f:
        data_words += line.strip().split()

# %%
data_words
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Alice',
#  'in',
#  'Wonderland,',
#  'by',
#  'Lewis',
#  'Carroll',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  'Title:',
#  'Alice',
#  'in',
#  'Wonderland',
#  'Author:',
#  'Lewis',
#  'Carroll',
#  'Illustrator:',
#  'Gordon',
#  'Robinson',
#  'Release',
#  'Date:',
#  'August',
#  '12,',
#  '2006',
#  '[EBook',
#  '#19033]',
#  'Language:',
#  'English',
#  '***',
#  'START',
#  'OF',
#  'THIS',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
# ...

# %%
len(data_words)
# Out:
# 12763

# %%
s = pd.Series(data=data_words)
s
# Out:
# 0             ﻿The
# 1          Project
# 2        Gutenberg
# 3            EBook
# 4               of
#            ...
# 12758           to
# 12759         hear
# 12760        about
# 12761          new
# 12762      eBooks.
# Length: 12763, dtype: object

# %%
s.value_counts()[:10]
# Out:
# the     732
# and     362
# a       321
# to      311
# of      300
# in      211
# she     197
# was     160
# said    129
# it      122
# Name: count, dtype: int64

# %%
s.str.lower().value_counts()[:10]
# Out:
# the    792
# and    379
# a      325
# to     318
# of     313
# she    232
# in     222
# was    160
# you    141
# it     136
# Name: count, dtype: int64

# %%
import string

# %%
s.str.strip(string.punctuation).str.lower().value_counts()[:10]
# Out:
# the    807
# and    404
# a      328
# to     327
# of     318
# she    237
# in     227
# it     183
# you    171
# was    168
# Name: count, dtype: int64

# %%
len(s.loc[s.str.istitle()])
# Out:
# 1531

# %%
len(s.loc[s.str.strip(string.punctuation + '"' + "'").str.istitle()])
# Out:
# 1531

# %%
s.str.lower().str.count('[aeiou]')
# Out:
# 0        1
# 1        2
# 2        3
# 3        3
# 4        1
#         ..
# 12758    1
# 12759    2
# 12760    3
# 12761    1
# 12762    3
# Length: 12763, dtype: int64

# %%
s.str.lower().str.count('[aeiou]').mean()
# Out:
# np.float64(1.66379377889211)

# %%
len(s.loc[s.str.contains(r'^[A-Z]\w*$', regex=True)])
# Out:
# 1100

# %%
s.loc[(s.str.istitle()) & ~(s.str.contains(r'^[A-Z]\w*$', regex=True))]
# Out:
# 0                ﻿The
# 7         Wonderland,
# 55             Title:
# 59            Author:
# 62       Illustrator:
#              ...
# 12573            U.S.
# 12626              S.
# 12687            U.S.
# 12694           Thus,
# 12742     Foundation,
# Length: 605, dtype: object

# %%
len(s.loc[s.str.contains(r'^[A-Z].*$', regex=True)])
# Out:
# 1532

# %%
s.loc[~(s.str.istitle()) & (s.str.contains(r'^[A-Z].*$', regex=True))]
# Out:
# 3                EBook
# 75               START
# 76                  OF
# 77                THIS
# 78             PROJECT
#              ...
# 12634     Gutenberg-tm
# 12657     Gutenberg-tm
# 12668     Gutenberg-tm
# 12719               PG
# 12730    Gutenberg-tm,
# Length: 331, dtype: object

# %%
# 36.1

# %%
s.str.strip(string.punctuation).loc[s.str.strip(string.punctuation).str.isdigit()].astype(int).mean()
# Out:
# np.float64(8030.851851851852)

# %%
# 36.2

# %%
alice_words = s.str.strip().str.strip(string.punctuation + "'" + '"').to_frame()

# %%
alice_words.columns = ['word']

# %%
alice_words
# Out:
#             word
# 0           ﻿The
# 1        Project
# 2      Gutenberg
# 3          EBook
# 4             of
# ...          ...
# 12758         to
# 12759       hear
# 12760      about
# 12761        new
# 12762     eBooks
#
# [12763 rows x 1 columns]

# %%
w = []
with open('data/words.txt', 'r') as f:
    for line in f:
        w += line.strip().split()

# %%
w
# Out:
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron',
#  'Aaronic',
#  'Aaronical',
#  'Aaronite',
#  'Aaronitic',
#  'Aaru',
#  'Ab',
#  'aba',
#  'Ababdeh',
#  'Ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'Abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'Abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'Abanic',
#  'Abantes',
#  'abaptiston',
#  'Abarambo',
#  'Abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'Abasgi',
#  'abash',
#  'abashed',
# ...

# %%
words = pd.DataFrame(data=w, columns=['word'])
words
# Out:
#               word
# 0                A
# 1                a
# 2               aa
# 3              aal
# 4            aalii
# ...            ...
# 235881      zythem
# 235882      Zythia
# 235883      zythum
# 235884     Zyzomys
# 235885  Zyzzogeton
#
# [235886 rows x 1 columns]

# %%
alice_words.merge(right=words, on=['word'], how='left', indicator=True).loc[lambda df_: df_['_merge'] == 'left_only']['word']
# Out:
# 0              ﻿The
# 1           Project
# 2         Gutenberg
# 3             EBook
# 7        Wonderland
#             ...
# 12741       Archive
# 12742    Foundation
# 12749        eBooks
# 12756         email
# 12762        eBooks
# Name: word, Length: 2503, dtype: object

# %%
# 36.3

# %%
with open('data/alice-in-wonderland.txt', 'r') as f:
    data_new = f.read().split('\n\n')

# %%
data_new
# Out:
# ['\ufeffThe Project Gutenberg EBook of Alice in Wonderland, by Lewis Carroll',
#  'This eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org',
#  '\nTitle: Alice in Wonderland',
#  'Author: Lewis Carroll',
#  'Illustrator: Gordon Robinson',
#  'Release Date: August 12, 2006 [EBook #19033]',
#  'Language: English',
#  '\n*** START OF THIS PROJECT GUTENBERG EBOOK ALICE IN WONDERLAND ***',
#  '',
#  '\nProduced by Jason Isbell, Irma Spehar, and the Online\nDistributed Proofreading Team at http://www.pgdp.net',
#  '',
#  '',
#  '',
#  '',
#  '          [Illustration: Alice in the Room of the Duchess.]',
#  '\n                       _THE "STORYLAND" SERIES_',
#  '',
#  "                   ALICE'S ADVENTURES IN WONDERLAND",
#  '',
#  '',
#  '',
# ...

# %%
s_new = pd.Series(data=data_new)
s_new
# Out:
# 0      ﻿The Project Gutenberg EBook of Alice in Wonde...
# 1      This eBook is for the use of anyone anywhere a...
# 2                           \nTitle: Alice in Wonderland
# 3                                  Author: Lewis Carroll
# 4                           Illustrator: Gordon Robinson
#                              ...
# 388    Professor Michael S. Hart is the originator of...
# 389    \nProject Gutenberg-tm eBooks are often create...
# 390    \nMost people start at our Web site which has ...
# 391                             http://www.gutenberg.org
# 392    This Web site includes information about Proje...
# Length: 393, dtype: object

# %%
s_new.str.split().str.len().loc[lambda x: x > 0].describe()
# Out:
# count    369.000000
# mean      34.588076
# std       32.356262
# min        1.000000
# 25%        9.000000
# 50%       24.000000
# 75%       52.000000
# max      169.000000
# dtype: float64
