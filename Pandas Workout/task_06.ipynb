# %%
import numpy as np
import pandas as pd

# %%
s = pd.read_csv('taxi-passenger-count.csv', header=None).squeeze()
s.name = 'taxi_passengers'

# %%
s.describe()
# Out:
# count    9999.000000
# mean        1.659466
# std         1.333306
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: taxi_passengers, dtype: float64

# %%
(s.value_counts(normalize=True) * 100).round(1).sort_index()
# Out:
# taxi_passengers
# 0     0.0
# 1    72.1
# 2    13.1
# 3     4.1
# 4     1.8
# 5     5.2
# 6     3.7
# Name: proportion, dtype: float64

# %%
# 6.1

# %%
s.describe()
# Out:
# count    9999.000000
# mean        1.659466
# std         1.333306
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: taxi_passengers, dtype: float64

# %%
# 6.2

# %%
(s.value_counts(normalize=True)[[3, 4, 5, 6]].sum() * 100).round(1)
# Out:
# np.float64(14.8)

# %%
# 6.3

# %%
# 1-2 passengers
