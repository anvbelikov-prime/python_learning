# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv', index_col=['Pokemon'])
pokemon = df.squeeze(axis='columns')

# %%
pokemon
# Out:
# Pokemon
# Bulbasaur      Grass / Poison
# Ivysaur        Grass / Poison
# Venusaur       Grass / Poison
# Charmander               Fire
# Charmeleon               Fire
#                     ...
# Stakataka        Rock / Steel
# Blacephalon      Fire / Ghost
# Zeraora              Electric
# Meltan                  Steel
# Melmetal                Steel
# Name: Type, Length: 809, dtype: object

# %%
google = pd.read_csv('google_stocks.csv', parse_dates=['Date'], index_col=['Date']).squeeze(axis='columns')

# %%
google
# Out:
# Date
# 2004-08-19      49.98
# 2004-08-20      53.95
# 2004-08-23      54.50
# 2004-08-24      52.24
# 2004-08-25      52.80
#                ...
# 2019-10-21    1246.15
# 2019-10-22    1242.80
# 2019-10-23    1259.13
# 2019-10-24    1260.99
# 2019-10-25    1265.13
# Name: Close, Length: 3824, dtype: float64

# %%
battles = pd.read_csv('revolutionary_war.csv', parse_dates=['Start Date'], index_col=['Start Date'], usecols=['Start Date', 'State']).squeeze(axis='columns')

# %%
battles
# Out:
# Start Date
# 1774-09-01    Massachusetts
# 1774-12-14    New Hampshire
# 1775-04-19    Massachusetts
# 1775-04-19    Massachusetts
# 1775-04-20         Virginia
#                   ...
# 1782-09-11         Virginia
# 1782-09-13              NaN
# 1782-10-18              NaN
# 1782-12-06              NaN
# 1783-01-22         Virginia
# Name: State, Length: 232, dtype: object

# %%
google
# Out:
# Date
# 2004-08-19      49.98
# 2004-08-20      53.95
# 2004-08-23      54.50
# 2004-08-24      52.24
# 2004-08-25      52.80
#                ...
# 2019-10-21    1246.15
# 2019-10-22    1242.80
# 2019-10-23    1259.13
# 2019-10-24    1260.99
# 2019-10-25    1265.13
# Name: Close, Length: 3824, dtype: float64

# %%
google.sort_values()
# Out:
# Date
# 2004-09-03      49.82
# 2004-09-01      49.94
# 2004-08-19      49.98
# 2004-09-02      50.57
# 2004-09-07      50.60
#                ...
# 2019-04-23    1264.55
# 2019-10-25    1265.13
# 2018-07-26    1268.33
# 2019-04-26    1272.18
# 2019-04-29    1287.58
# Name: Close, Length: 3824, dtype: float64

# %%
google.sort_values(ascending=False)
# Out:
# Date
# 2019-04-29    1287.58
# 2019-04-26    1272.18
# 2018-07-26    1268.33
# 2019-10-25    1265.13
# 2019-04-23    1264.55
#                ...
# 2004-09-07      50.60
# 2004-09-02      50.57
# 2004-08-19      49.98
# 2004-09-01      49.94
# 2004-09-03      49.82
# Name: Close, Length: 3824, dtype: float64

# %%
pokemon
# Out:
# Pokemon
# Bulbasaur      Grass / Poison
# Ivysaur        Grass / Poison
# Venusaur       Grass / Poison
# Charmander               Fire
# Charmeleon               Fire
#                     ...
# Stakataka        Rock / Steel
# Blacephalon      Fire / Ghost
# Zeraora              Electric
# Meltan                  Steel
# Melmetal                Steel
# Name: Type, Length: 809, dtype: object

# %%
pokemon.sort_values()
# Out:
# Pokemon
# Illumise                Bug
# Silcoon                 Bug
# Pinsir                  Bug
# Burmy                   Bug
# Wurmple                 Bug
#                   ...
# Tirtouga       Water / Rock
# Relicanth      Water / Rock
# Corsola        Water / Rock
# Carracosta     Water / Rock
# Empoleon      Water / Steel
# Name: Type, Length: 809, dtype: object

# %%
battles.sort_values(na_position='first')
# Out:
# Start Date
# 1775-09-17         NaN
# 1775-12-31         NaN
# 1776-03-03         NaN
# 1776-03-25         NaN
# 1776-05-18         NaN
#                 ...
# 1781-07-06    Virginia
# 1781-07-01    Virginia
# 1781-06-26    Virginia
# 1781-04-25    Virginia
# 1783-01-22    Virginia
# Name: State, Length: 232, dtype: object

# %%
battles.dropna().sort_values()
# Out:
# Start Date
# 1781-09-06    Connecticut
# 1779-07-05    Connecticut
# 1777-04-27    Connecticut
# 1777-09-03       Delaware
# 1777-05-17        Florida
#                  ...
# 1781-07-06       Virginia
# 1781-07-01       Virginia
# 1781-06-26       Virginia
# 1781-04-25       Virginia
# 1783-01-22       Virginia
# Name: State, Length: 162, dtype: object

# %%
s = pd.Series(data=[1, 2, 3], index=[np.nan, 'b', np.nan])
s
# Out:
# NaN    1
# b      2
# NaN    3
# dtype: int64

# %%
s.loc[np.nan]
# Out:
# NaN    1
# NaN    3
# dtype: int64

# %%
s.dropna()
# Out:
# NaN    1
# b      2
# NaN    3
# dtype: int64

# %%
s.reset_index()
# Out:
#   index  0
# 0   NaN  1
# 1     b  2
# 2   NaN  3

# %%
s.reset_index().drop(columns='index').squeeze(axis=1)
# Out:
# 0    1
# 1    2
# 2    3
# Name: 0, dtype: int64

# %%
pokemon.sort_index(ascending=False)
# Out:
# Pokemon
# Zygarde      Dragon / Ground
# Zweilous       Dark / Dragon
# Zubat        Poison / Flying
# Zorua                   Dark
# Zoroark                 Dark
#                   ...
# Aegislash      Steel / Ghost
# Accelgor                 Bug
# Absol                   Dark
# Abra                 Psychic
# Abomasnow        Grass / Ice
# Name: Type, Length: 809, dtype: object

# %%
pokemon.sort_index()
# Out:
# Pokemon
# Abomasnow        Grass / Ice
# Abra                 Psychic
# Absol                   Dark
# Accelgor                 Bug
# Aegislash      Steel / Ghost
#                   ...
# Zoroark                 Dark
# Zorua                   Dark
# Zubat        Poison / Flying
# Zweilous       Dark / Dragon
# Zygarde      Dragon / Ground
# Name: Type, Length: 809, dtype: object

# %%
battles.sort_index(na_position='first')
# Out:
# Start Date
# NaT              New Jersey
# NaT                Virginia
# NaT                     NaN
# NaT                     NaN
# 1774-09-01    Massachusetts
#                   ...
# 1782-09-11         Virginia
# 1782-09-13              NaN
# 1782-10-18              NaN
# 1782-12-06              NaN
# 1783-01-22         Virginia
# Name: State, Length: 232, dtype: object

# %%
google.sort_values(ascending=False).head()
# Out:
# Date
# 2019-04-29    1287.58
# 2019-04-26    1272.18
# 2018-07-26    1268.33
# 2019-10-25    1265.13
# 2019-04-23    1264.55
# Name: Close, dtype: float64

# %%
google.nlargest()
# Out:
# Date
# 2019-04-29    1287.58
# 2019-04-26    1272.18
# 2018-07-26    1268.33
# 2019-10-25    1265.13
# 2019-04-23    1264.55
# Name: Close, dtype: float64

# %%
google.nsmallest()
# Out:
# Date
# 2004-09-03    49.82
# 2004-09-01    49.94
# 2004-08-19    49.98
# 2004-09-02    50.57
# 2004-09-07    50.60
# Name: Close, dtype: float64

# %%
pokemon.value_counts()
# Out:
# Type
# Normal                65
# Water                 61
# Grass                 38
# Psychic               35
# Fire                  30
#                       ..
# Fire / Psychic         1
# Normal / Ground        1
# Psychic / Fighting     1
# Dark / Ghost           1
# Fire / Ghost           1
# Name: count, Length: 159, dtype: int64

# %%
pokemon
# Out:
# Pokemon
# Bulbasaur      Grass / Poison
# Ivysaur        Grass / Poison
# Venusaur       Grass / Poison
# Charmander               Fire
# Charmeleon               Fire
#                     ...
# Stakataka        Rock / Steel
# Blacephalon      Fire / Ghost
# Zeraora              Electric
# Meltan                  Steel
# Melmetal                Steel
# Name: Type, Length: 809, dtype: object

# %%
pokemon.value_counts()
# Out:
# Type
# Normal                65
# Water                 61
# Grass                 38
# Psychic               35
# Fire                  30
#                       ..
# Fire / Psychic         1
# Normal / Ground        1
# Psychic / Fighting     1
# Dark / Ghost           1
# Fire / Ghost           1
# Name: count, Length: 159, dtype: int64

# %%
s
# Out:
# NaN    1
# b      2
# NaN    3
# dtype: int64

# %%
s = pd.Series([1, 2, 3, 3, np.nan])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    NaN
# dtype: float64

# %%
s.value_counts()
# Out:
# 3.0    2
# 1.0    1
# 2.0    1
# Name: count, dtype: int64

# %%
(pokemon.value_counts(normalize=True) * 100).round(2)
# Out:
# Type
# Normal                8.03
# Water                 7.54
# Grass                 4.70
# Psychic               4.33
# Fire                  3.71
#                       ...
# Fire / Psychic        0.12
# Normal / Ground       0.12
# Psychic / Fighting    0.12
# Dark / Ghost          0.12
# Fire / Ghost          0.12
# Name: proportion, Length: 159, dtype: float64

# %%
google.value_counts()
# Out:
# Close
# 287.68     3
# 194.27     3
# 307.10     3
# 288.92     3
# 290.41     3
#           ..
# 292.43     1
# 293.41     1
# 296.75     1
# 295.46     1
# 1265.13    1
# Name: count, Length: 3696, dtype: int64

# %%
google.max()
# Out:
# 1287.58

# %%
google.min()
# Out:
# 49.82

# %%
buckets = list(range(0, 1401, 200))

# %%
buckets
# Out:
# [0, 200, 400, 600, 800, 1000, 1200, 1400]

# %%
google.value_counts(bins=buckets).sort_index()
# Out:
# (-0.001, 200.0]      595
# (200.0, 400.0]      1568
# (400.0, 600.0]       575
# (600.0, 800.0]       380
# (800.0, 1000.0]      207
# (1000.0, 1200.0]     406
# (1200.0, 1400.0]      93
# Name: count, dtype: int64

# %%
google.value_counts(bins=buckets, sort=False)
# Out:
# (-0.001, 200.0]      595
# (200.0, 400.0]      1568
# (400.0, 600.0]       575
# (600.0, 800.0]       380
# (800.0, 1000.0]      207
# (1000.0, 1200.0]     406
# (1200.0, 1400.0]      93
# Name: count, dtype: int64

# %%
google.value_counts(bins=6, sort=False)
# Out:
# (48.581, 256.113]      1204
# (256.113, 462.407]     1104
# (462.407, 668.7]        507
# (668.7, 874.993]        380
# (874.993, 1081.287]     292
# (1081.287, 1287.58]     337
# Name: count, dtype: int64

# %%
battles.value_counts(dropna=False)
# Out:
# State
# NaN               70
# South Carolina    31
# New York          28
# New Jersey        24
# Virginia          21
# Massachusetts     11
# Pennsylvania      10
# North Carolina     9
# Florida            8
# Georgia            6
# Rhode Island       3
# Connecticut        3
# Vermont            3
# New Hampshire      1
# Delaware           1
# Indiana            1
# Louisiana          1
# Ohio               1
# Name: count, dtype: int64

# %%
battles.index.value_counts()
# Out:
# Start Date
# 1781-04-25    2
# 1781-05-22    2
# 1780-08-18    2
# 1781-09-13    2
# 1782-03-16    2
#              ..
# 1778-06-30    1
# 1778-07-03    1
# 1778-07-27    1
# 1778-08-21    1
# 1783-01-22    1
# Name: count, Length: 217, dtype: int64

# %%
google.apply(np.round)
# Out:
# Date
# 2004-08-19      50.0
# 2004-08-20      54.0
# 2004-08-23      54.0
# 2004-08-24      52.0
# 2004-08-25      53.0
#                ...
# 2019-10-21    1246.0
# 2019-10-22    1243.0
# 2019-10-23    1259.0
# 2019-10-24    1261.0
# 2019-10-25    1265.0
# Name: Close, Length: 3824, dtype: float64

# %%
def single_or_multi(pokemon_type):
    if '/' in pokemon_type:
        return 'Multi'
    else:
        return 'Single'

# %%
(pokemon.apply(single_or_multi).value_counts(normalize=True) * 100).round(1)
# Out:
# Type
# Multi     50.1
# Single    49.9
# Name: proportion, dtype: float64

# %%
# Exercies

# %%
#1

# %%
import datetime as dt

# %%
battles = pd.read_csv('revolutionary_war.csv', usecols=['Start Date'], parse_dates=['Start Date']).squeeze(axis=1)

# %%
battles
# Out:
# 0     1774-09-01
# 1     1774-12-14
# 2     1775-04-19
# 3     1775-04-19
# 4     1775-04-20
#          ...
# 227   1782-09-11
# 228   1782-09-13
# 229   1782-10-18
# 230   1782-12-06
# 231   1783-01-22
# Name: Start Date, Length: 232, dtype: datetime64[ns]

# %%
battles.dropna().apply(lambda d: d.strftime('%A')).value_counts()
# Out:
# Start Date
# Saturday     39
# Friday       39
# Wednesday    32
# Thursday     31
# Sunday       31
# Tuesday      29
# Monday       27
# Name: count, dtype: int64
