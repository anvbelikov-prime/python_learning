# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4, 5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.nunique()
# Out:
# 5

# %%
s.sum()
# Out:
# np.int64(15)

# %%
s.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.tail()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
s.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
s = pd.Series([1, 2, 3], dtype=np.float16)

# %%
s
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float16

# %%
s.astype(np.int8)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int8

# %%
s.astype(np.bool)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
s = pd.Series(data=[1, 2, 3, np.nan, 4, 5])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
s.ffill()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    4.0
# 5    5.0
# dtype: float64

# %%
s.bfill()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    4.0
# 5    5.0
# dtype: float64
