# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 'a'])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    a
# dtype: object

# %%
s = pd.Series([1, 2, 3, 4, 5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
string_list = ['a', 'b', 'c', 'd', 'e']

# %%
s = pd.Series(string_list)

# %%
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
s = pd.Series(data=string_list)

# %%
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
index_list = ['a', 'b', 'c', 'd', 'e']

# %%
s = pd.Series(data=string_list, index=index_list)

# %%
s
# Out:
# a    a
# b    b
# c    c
# d    d
# e    e
# dtype: object

# %%
s['a']
# Out:
# 'a'

# %%
s.a
# Out:
# 'a'

# %%
s.d
# Out:
# 'd'

# %%
index_list = ['aa', 'bb', 'cc', 'dd', 'ee']

# %%
s = pd.Series(data=string_list, index=index_list)

# %%
s
# Out:
# aa    a
# bb    b
# cc    c
# dd    d
# ee    e
# dtype: object

# %%
s['aa']
# Out:
# 'a'

# %%
s.aa
# Out:
# 'a'

# %%
s[0]
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_3966/243613605.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# 'a'

# %%
s.iloc[0]
# Out:
# 'a'

# %%
index_list = ['aa', 'aa', 'bb', 'bb', 'cc']

# %%
s = pd.Series(index=index_list, data=string_list)
s
# Out:
# aa    a
# aa    b
# bb    c
# bb    d
# cc    e
# dtype: object

# %%
s['aa']
# Out:
# aa    a
# aa    b
# dtype: object

# %%
s = pd.Series([True, False, False])
s
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
s = pd.Series([1, 2, 3, 4, 5], dtype=np.float64)
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
temperatures = [15, 12, 8, 14, np.nan, 10, 6, 2]

# %%
s = pd.Series(data=temperatures)
s
# Out:
# 0    15.0
# 1    12.0
# 2     8.0
# 3    14.0
# 4     NaN
# 5    10.0
# 6     6.0
# 7     2.0
# dtype: float64

# %%
simple_dict = {'a':1.5, 'b':2, 'c':3}
s = pd.Series(data=simple_dict)
s
# Out:
# a    1.5
# b    2.0
# c    3.0
# dtype: float64

# %%
simple_tuple = (1, 2, 3, 4, 5)
s = pd.Series(data=simple_tuple)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
complex_tuple = ((1, 2, 3), (4, 5, 6), (7, 8, 9))
s = pd.Series(data=complex_tuple)
s
# Out:
# 0    (1, 2, 3)
# 1    (4, 5, 6)
# 2    (7, 8, 9)
# dtype: object

# %%
simple_set = {'a', 'z', 'e', 'l'}

# %%
simple_set
# Out:
# {'a', 'e', 'l', 'z'}

# %%
s = pd.Series(data=simple_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s = pd.Series(data=simple_set)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/construction.py:639, in sanitize_array(data, index, dtype, copy, allow_2d)
#     630     return sanitize_array(
#     631         data,
#     632         index=index,
#    (...)
#     635         allow_2d=allow_2d,
#     636     )
#     638 else:
# --> 639     _sanitize_non_ordered(data)
# ...

# %%
s = pd.Series(data=sorted(list(simple_set)))
s
# Out:
# 0    a
# 1    e
# 2    l
# 3    z
# dtype: object

# %%
rand_ints = np.random.randint(1, 101, 10)
rand_ints
# Out:
# array([49, 75,  9, 66, 44, 92, 81, 47, 45, 11])

# %%
s = pd.Series(data=rand_ints)
s
# Out:
# 0    49
# 1    75
# 2     9
# 3    66
# 4    44
# 5    92
# 6    81
# 7    47
# 8    45
# 9    11
# dtype: int64

# %%
s.values
# Out:
# array([49, 75,  9, 66, 44, 92, 81, 47, 45, 11])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
values_list = [1, 2, 3, 4, 5]
index_list = ['a', 'b', 'c', 'd', 'e']

# %%
s = pd.Series(data=values_list, index=index_list)

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
type(s.values)
# Out:
# numpy.ndarray

# %%
type(s.index)
# Out:
# pandas.core.indexes.base.Index

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 5

# %%
s.shape
# Out:
# (5,)

# %%
len(s)
# Out:
# 5

# %%
s.is_unique
# Out:
# True

# %%
s.is_monotonic_increasing
# Out:
# True

# %%
s.is_monotonic_decreasing
# Out:
# False

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s['b'] = np.nan

# %%
s
# Out:
# a    1.0
# b    NaN
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
s.is_unique
# Out:
# True

# %%
s['c'] = np.nan

# %%
s
# Out:
# a    1.0
# b    NaN
# c    NaN
# d    4.0
# e    5.0
# dtype: float64

# %%
s.is_unique
# Out:
# False

# %%
values = range(0, 501, 5)
nums = pd.Series(data=values)

# %%
nums
# Out:
# 0        0
# 1        5
# 2       10
# 3       15
# 4       20
#       ...
# 96     480
# 97     485
# 98     490
# 99     495
# 100    500
# Length: 101, dtype: int64

# %%
nums.head(3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.tail(10)
# Out:
# 91     455
# 92     460
# 93     465
# 94     470
# 95     475
# 96     480
# 97     485
# 98     490
# 99     495
# 100    500
# dtype: int64

# %%
nums
# Out:
# 0        0
# 1        5
# 2       10
# 3       15
# 4       20
#       ...
# 96     480
# 97     485
# 98     490
# 99     495
# 100    500
# Length: 101, dtype: int64

# %%
numbers = pd.Series([1, 2, 3, np.nan, 4, 5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
len(numbers)
# Out:
# 6

# %%
numbers.sum()
# Out:
# np.float64(15.0)

# %%
numbers.sum(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.sum(min_count=6)
# Out:
# np.float64(nan)

# %%
numbers.sum(min_count=5)
# Out:
# np.float64(15.0)

# %%
numbers.product()
# Out:
# np.float64(120.0)

# %%
numbers.product(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna=False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers.pct_change()
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_3966/527026991.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
(4 - 3)/ 3
# Out:
# 0.3333333333333333

# %%
(5 - 4) / 4
# Out:
# 0.25

# %%
numbers.pct_change(fill_method='bfill')
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_3966/629865841.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='bfill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
numbers.fillna(method='ffill').pct_change()
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_3966/1338011009.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numbers.fillna(method='ffill').pct_change()
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers.ffill().pct_change()
# Out:
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers.bfill().pct_change()
# Out:
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
numbers.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.mean()
# Out:
# np.float64(3.0)

# %%
numbers.median()
# Out:
# 3.0

# %%
numbers.std()
# Out:
# 1.5811388300841898

# %%
numbers.max()
# Out:
# 5.0

# %%
numbers.min()
# Out:
# 1.0

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
pd.Series(['a', 'z', 'h']).max()
# Out:
# 'z'

# %%
pd.Series(['a', 'z', 'h']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 pd.Series(['a', 'z', 'h']).mean()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)
#    6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# ...

# %%
numbers.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
numbers.sample(3)
# Out:
# 3    NaN
# 0    1.0
# 4    4.0
# dtype: float64

# %%
numbers.unique()
# Out:
# array([ 1.,  2.,  3., nan,  4.,  5.])

# %%
numbers.nunique()
# Out:
# 5

# %%
len(numbers)
# Out:
# 6

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
nums = numbers.fillna(0)

# %%
nums
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# 4    4.0
# 5    5.0
# dtype: float64

# %%
nums = nums.astype(np.int8)

# %%
nums
# Out:
# 0    1
# 1    2
# 2    3
# 3    0
# 4    4
# 5    5
# dtype: int8

# %%
numbers.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6 entries, 0 to 5
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      float64
# dtypes: float64(1)
# memory usage: 180.0 bytes

# %%
nums.memory_usage()
# Out:
# 138

# %%
numbers.memory_usage()
# Out:
# 180

# %%
s = pd.Series(data=[5, np.nan, 15], index=['a', 'b', 'c'])

# %%
s
# Out:
# a     5.0
# b     NaN
# c    15.0
# dtype: float64

# %%
s +3
# Out:
# a     8.0
# b     NaN
# c    18.0
# dtype: float64

# %%
s // 4
# Out:
# a    1.0
# b    NaN
# c    3.0
# dtype: float64

# %%
s % 3
# Out:
# a    2.0
# b    NaN
# c    0.0
# dtype: float64

# %%
s1 = pd.Series([1, 2,  np.nan, 3])
s2 = pd.Series([2, 2, np.nan, 3])

# %%
s1 == s2
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1 != s2
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s1 + s2
# Out:
# 0    3.0
# 1    4.0
# 2    NaN
# 3    6.0
# dtype: float64

# %%
s1 = pd.Series(data=[1, 2,  np.nan, 3], index=['a', 'b', 'c', 'd'])
s2 = pd.Series(data=[2, 2, np.nan, 3], index=['a', 'b', 'f', 'd'])

# %%
s1 + s2
# Out:
# a    3.0
# b    4.0
# c    NaN
# d    6.0
# f    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
dict(numbers)
# Out:
# {0: np.float64(1.0),
#  1: np.float64(2.0),
#  2: np.float64(3.0),
#  3: np.float64(nan),
#  4: np.float64(4.0),
#  5: np.float64(5.0)}

# %%
2 in numbers
# Out:
# True

# %%
'a' in numbers
# Out:
# False

# %%
numbers = pd.Series([100, 200, 300])

# %%
numbers
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
2 in numbers
# Out:
# True

# %%
100 in numbers
# Out:
# False

# %%
100 in numbers.values
# Out:
# True

# %%
# Exercises

# %%
superheroes = [
    'Batman',
    'Superman',
    'Spider-Man',
    'Iron Man',
    'Captain America',
    'Wonder Woman'
]

# %%
strength_levels = (100, 120, 90, 95, 110, 120)

# %%
len(superheroes) == len(strength_levels)
# Out:
# True

# %%
# 1

# %%
heroes = pd.Series(data=superheroes)
heroes
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-Man
# 3           Iron Man
# 4    Captain America
# 5       Wonder Woman
# dtype: object

# %%
# 2

# %%
strengths = pd.Series(data=strength_levels)
strengths
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
# 3

# %%
heroes = pd.Series(data=superheroes, index=strength_levels)
heroes
# Out:
# 100             Batman
# 120           Superman
# 90          Spider-Man
# 95            Iron Man
# 110    Captain America
# 120       Wonder Woman
# dtype: object

# %%
# 4

# %%
heroes.head(2)
# Out:
# 100      Batman
# 120    Superman
# dtype: object

# %%
heroes.iloc[0:1]
# Out:
# 100    Batman
# dtype: object

# %%
heroes.iloc[0:2]
# Out:
# 100      Batman
# 120    Superman
# dtype: object

# %%
# 5

# %%
heroes.tail(4)
# Out:
# 90          Spider-Man
# 95            Iron Man
# 110    Captain America
# 120       Wonder Woman
# dtype: object

# %%
heroes.iloc[-4:]
# Out:
# 90          Spider-Man
# 95            Iron Man
# 110    Captain America
# 120       Wonder Woman
# dtype: object

# %%
# 6

# %%
heroes.nunique()
# Out:
# 6

# %%
len(heroes)
# Out:
# 6

# %%
# 7

# %%
heroes = pd.Series(index=superheroes, data=strength_levels)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes = pd.Series(index=superheroes, data=strength_levels)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.mean()
# Out:
# np.float64(105.83333333333333)

# %%
heroes.nunique()
# Out:
# 5

# %%
len(heroes)
# Out:
# 6

# %%
# 8

# %%
heroes.min()
# Out:
# 90

# %%
heroes.max()
# Out:
# 120

# %%
# 9

# %%
heroes * 2
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
# 10

# %%
dict(heroes)
# Out:
# {'Batman': np.int64(100),
#  'Superman': np.int64(120),
#  'Spider-Man': np.int64(90),
#  'Iron Man': np.int64(95),
#  'Captain America': np.int64(110),
#  'Wonder Woman': np.int64(120)}
