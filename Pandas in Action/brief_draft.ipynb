# %%
import numpy as np
import pandas as pd

# %%
pd.isna(np.nan)
# Out:
# True

# %%
s = pd.Series(data=[1, 2, 3], index=['a', 'b', 'c'], dtype=np.int8, name='tmp_series')
s
# Out:
# a    1
# b    2
# c    3
# Name: tmp_series, dtype: int8

# %%
s.empty
# Out:
# False

# %%
s.unique
# Out:
# <bound method Series.unique of a    1
# b    2
# c    3
# Name: tmp_series, dtype: int8>

# %%
s.is_unique
# Out:
# True

# %%
s.is_monotonic_increasing
# Out:
# True

# %%
s.is_monotonic_decreasing
# Out:
# False

# %%
s.size
# Out:
# 3

# %%
s.count()
# Out:
# np.int64(3)

# %%
s.size - s.count()
# Out:
# np.int64(0)

# %%
s.loc['d'] = np.nan
s.loc['e'] = 7
s.loc['f'] = np.nan
s.loc['g'] = 9

# %%
s
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# e    7.0
# f    NaN
# g    9.0
# Name: tmp_series, dtype: float64

# %%
s.ffill()
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    3.0
# e    7.0
# f    7.0
# g    9.0
# Name: tmp_series, dtype: float64

# %%
s.bfill()
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    7.0
# e    7.0
# f    9.0
# g    9.0
# Name: tmp_series, dtype: float64

# %%
s.ffill().diff(2)
# Out:
# a    NaN
# b    NaN
# c    2.0
# d    1.0
# e    4.0
# f    4.0
# g    2.0
# Name: tmp_series, dtype: float64

# %%
s.pct_change()
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_5199/1985440233.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   s.pct_change()
# a         NaN
# b    1.000000
# c    0.500000
# d    0.000000
# e    1.333333
# f    0.000000
# g    0.285714
# Name: tmp_series, dtype: float64

# %%
s.ffill().pct_change()
# Out:
# a         NaN
# b    1.000000
# c    0.500000
# d    0.000000
# e    1.333333
# f    0.000000
# g    0.285714
# Name: tmp_series, dtype: float64

# %%
s.unique()
# Out:
# array([ 1.,  2.,  3., nan,  7.,  9.])

# %%
s.nunique()
# Out:
# 5

# %%
s.dropna()
# Out:
# a    1.0
# b    2.0
# c    3.0
# e    7.0
# g    9.0
# Name: tmp_series, dtype: float64

# %%
s.fillna(0)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    0.0
# e    7.0
# f    0.0
# g    9.0
# Name: tmp_series, dtype: float64

# %%
s.fillna(0).cumsum()
# Out:
# a     1.0
# b     3.0
# c     6.0
# d     6.0
# e    13.0
# f    13.0
# g    22.0
# Name: tmp_series, dtype: float64

# %%
s.fillna(1).cumprod()
# Out:
# a      1.0
# b      2.0
# c      6.0
# d      6.0
# e     42.0
# f     42.0
# g    378.0
# Name: tmp_series, dtype: float64

# %%
s.sample(3)
# Out:
# c    3.0
# b    2.0
# a    1.0
# Name: tmp_series, dtype: float64

# %%
s.head()
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# e    7.0
# Name: tmp_series, dtype: float64

# %%
s.tail()
# Out:
# c    3.0
# d    NaN
# e    7.0
# f    NaN
# g    9.0
# Name: tmp_series, dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
s.loc['h'] = -10

# %%
s
# Out:
# a     1.0
# b     2.0
# c     3.0
# d     NaN
# e     7.0
# f     NaN
# g     9.0
# h   -10.0
# Name: tmp_series, dtype: float64

# %%
s.sort_values(ascending=False, na_position='first')
# Out:
# d     NaN
# f     NaN
# g     9.0
# e     7.0
# c     3.0
# b     2.0
# a     1.0
# h   -10.0
# Name: tmp_series, dtype: float64

# %%
s.sort_values(ascending=False, na_position='last', key=lambda x: x ** 2)
# Out:
# h   -10.0
# g     9.0
# e     7.0
# c     3.0
# b     2.0
# a     1.0
# d     NaN
# f     NaN
# Name: tmp_series, dtype: float64

# %%
s.sort_index()
# Out:
# a     1.0
# b     2.0
# c     3.0
# d     NaN
# e     7.0
# f     NaN
# g     9.0
# h   -10.0
# Name: tmp_series, dtype: float64

# %%
s.idxmax()
# Out:
# 'g'

# %%
s.idxmin()
# Out:
# 'h'

# %%
s
# Out:
# a     1.0
# b     2.0
# c     3.0
# d     NaN
# e     7.0
# f     NaN
# g     9.0
# h   -10.0
# Name: tmp_series, dtype: float64

# %%
s.value_counts()
# Out:
# tmp_series
#  1.0     1
#  2.0     1
#  3.0     1
#  7.0     1
#  9.0     1
# -10.0    1
# Name: count, dtype: int64

# %%
s.value_counts(normalize=True)
# Out:
# tmp_series
#  1.0     0.166667
#  2.0     0.166667
#  3.0     0.166667
#  7.0     0.166667
#  9.0     0.166667
# -10.0    0.166667
# Name: proportion, dtype: float64

# %%
s.value_counts(normalize=True).sum()
# Out:
# np.float64(0.9999999999999999)

# %%
s.value_counts(ascending=False)
# Out:
# tmp_series
#  1.0     1
#  2.0     1
#  3.0     1
#  7.0     1
#  9.0     1
# -10.0    1
# Name: count, dtype: int64

# %%
s.value_counts(ascending=True)
# Out:
# tmp_series
#  1.0     1
#  2.0     1
#  3.0     1
#  7.0     1
#  9.0     1
# -10.0    1
# Name: count, dtype: int64

# %%
s.value_counts(bins=3, sort=False)
# Out:
# (-10.02, -3.667]    1
# (-3.667, 2.667]     2
# (2.667, 9.0]        3
# Name: count, dtype: int64

# %%
pd.cut(s, bins=[-10, -5, -3, -1, 0, 1, 3, 5, 11], labels=['-10', '-5', '-3', '-1', '1', '3', '5', '10'], include_lowest=True)
# Out:
# a      1
# b      3
# c      3
# d    NaN
# e     10
# f    NaN
# g     10
# h    -10
# Name: tmp_series, dtype: category
# Categories (8, object): ['-10' < '-5' < '-3' < '-1' < '1' < '3' < '5' < '10']

# %%
conditions=[
    s < -5,
    (s >= -5) & (s < 0),
    (s >= 0) & (s < 5),
    (s >= 5) & (s <= 10)
]

# %%
choices=[
    'cat_1',
    'cat_2',
    'cat_3',
    'cat_4'
]

# %%
np.select(conditions, choices, 'other')
# Out:
# array(['cat_3', 'cat_3', 'cat_3', 'other', 'cat_4', 'other', 'cat_4',
#        'cat_1'], dtype='<U5')

# %%
def my_func(val, par1, par2):
    if pd.isna(val):
        return par1
    elif val < 0:
        return par2
    else:
        return str(val)

# %%
s.apply(func=my_func, par1='null', par2='neg')
# Out:
# a     1.0
# b     2.0
# c     3.0
# d    null
# e     7.0
# f    null
# g     9.0
# h     neg
# Name: tmp_series, dtype: object

# %%
np.random.random((3, 2))
# Out:
# array([[0.8001757 , 0.92959861],
#        [0.3985874 , 0.20764905],
#        [0.47431387, 0.28461735]])

# %%
np.random.rand(10)
# Out:
# array([0.86610063, 0.73248896, 0.95965948, 0.91126096, 0.06623019,
#        0.16025456, 0.86061243, 0.23937018, 0.72459075, 0.58598907])

# %%
np.random.randint(1, 101, (10,10))
# Out:
# array([[ 97,  17,  36,   6,  10,  31,  37,  19,  47,  35],
#        [ 86,  95,  72,  51,  71,  91,  81,  24,  74,  11],
#        [ 78,  18,  13,  67,  38,  40,  55,  59,  55,  37],
#        [ 32,  49,  42,  28,  47,  80,  30,  55,  13,  93],
#        [ 54,  96,  16,  44,  83,  21,  70,  10,  59,  95],
#        [ 92,  65,   6,  55,  60,  26,  56,  13,  97,  38],
#        [  2, 100,  27,   9,  10,  25,   7,  43,  25,  19],
#        [ 76,  59,  52,  72,   5,   2,   8,  96,  30,  52],
#        [ 34,  32,  19,  12,   8,  52,  30,  69,  97,  30],
#        [ 61,  38,  97,  36,  68,  69,  50,  83,  23,  11]])

# %%
pd.Series(np.random.normal(0, 1, 1_000_000)).value_counts(bins=1000, sort=False).plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(data=s)
df
# Out:
#    tmp_series
# a         1.0
# b         2.0
# c         3.0
# d         NaN
# e         7.0
# f         NaN
# g         9.0
# h       -10.0

# %%
s.sum(skipna=True, min_count=7)
# Out:
# np.float64(nan)

# %%
df.sum(numeric_only=True, min_count=3)
# Out:
# tmp_series    12.0
# dtype: float64

# %%
s.describe()
# Out:
# count     6.00000
# mean      2.00000
# std       6.63325
# min     -10.00000
# 25%       1.25000
# 50%       2.50000
# 75%       6.00000
# max       9.00000
# Name: tmp_series, dtype: float64

# %%
df.describe()
# Out:
#        tmp_series
# count     6.00000
# mean      2.00000
# std       6.63325
# min     -10.00000
# 25%       1.25000
# 50%       2.50000
# 75%       6.00000
# max       9.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to h
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tmp_series  6 non-null      float64
# dtypes: float64(1)
# memory usage: 428.0+ bytes

# %%
df[df['tmp_series'].isnull()]
# Out:
#    tmp_series
# d         NaN
# f         NaN

# %%
df[(df['tmp_series'].isnull()) | (df['tmp_series'] > 0)]
# Out:
#    tmp_series
# a         1.0
# b         2.0
# c         3.0
# d         NaN
# e         7.0
# f         NaN
# g         9.0

# %%
df.loc[(df['tmp_series'].isnull()) | (df['tmp_series'] > 0), :]
# Out:
#    tmp_series
# a         1.0
# b         2.0
# c         3.0
# d         NaN
# e         7.0
# f         NaN
# g         9.0

# %%
df = df.reset_index()

# %%
df
# Out:
#   index  tmp_series
# 0     a         1.0
# 1     b         2.0
# 2     c         3.0
# 3     d         NaN
# 4     e         7.0
# 5     f         NaN
# 6     g         9.0
# 7     h       -10.0

# %%
df = df.rename(columns={'index':'cat'})
df
# Out:
#   cat  tmp_series
# 0   a         1.0
# 1   b         2.0
# 2   c         3.0
# 3   d         NaN
# 4   e         7.0
# 5   f         NaN
# 6   g         9.0
# 7   h       -10.0

# %%
df.loc[:, 'cat'].str.replace('a', 'aa')
# Out:
# 0    aa
# 1     b
# 2     c
# 3     d
# 4     e
# 5     f
# 6     g
# 7     h
# Name: cat, dtype: object

# %%
g = df.groupby(by=['cat'])

# %%
g.max()
# Out:
#      tmp_series
# cat
# a           1.0
# b           2.0
# c           3.0
# d           NaN
# e           7.0
# f           NaN
# g           9.0
# h         -10.0

# %%
g[['tmp_series']].max()
# Out:
#      tmp_series
# cat
# a           1.0
# b           2.0
# c           3.0
# d           NaN
# e           7.0
# f           NaN
# g           9.0
# h         -10.0

# %%
g.agg(['mean', 'max', 'min']).stack()
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_5199/2200044750.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   g.agg(['mean', 'max', 'min']).stack()
#           tmp_series
# cat
# a   mean         1.0
#     max          1.0
#     min          1.0
# b   mean         2.0
#     max          2.0
#     min          2.0
# c   mean         3.0
#     max          3.0
#     min          3.0
# e   mean         7.0
#     max          7.0
#     min          7.0
# g   mean         9.0
#     max          9.0
#     min          9.0
# h   mean       -10.0
#     max        -10.0
#     min        -10.0
