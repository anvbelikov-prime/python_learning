# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# %matplotlib inline

# %%
df = pd.read_csv('space_missions.csv', parse_dates=['Date'], index_col=0)
df
# Out:
# /var/folders/d6/q237b0c90bqfq_8yty4yh1v40000gn/T/ipykernel_4106/912190214.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('space_missions.csv', parse_dates=['Date'], index_col=0)
#            Company Name    Location    Cost   Status
# Date
# 2019-02-05  Arianespace      France  200.00  Success
# 2019-02-22       SpaceX         USA   50.00  Success
# 2019-03-02       SpaceX         USA   50.00  Success
# 2019-03-09         CASC       China   29.15  Success
# 2019-03-22  Arianespace      France   37.00  Success
# ...                 ...         ...     ...      ...
# 2020-07-25         CASC       China   64.68  Success
# 2020-07-30          ULA         USA  145.00  Success
# 2020-07-30    Roscosmos  Kazakhstan   65.00  Success
# 2020-08-06         CASC       China   29.75  Success
# ...

# %%
df['Cost'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(y='Cost', colormap='summer')
# Out:
# <Axes: xlabel='Date'>

# %%
df.head()
# Out:
#            Company Name Location    Cost   Status
# Date
# 2019-02-05  Arianespace   France  200.00  Success
# 2019-02-22       SpaceX      USA   50.00  Success
# 2019-03-02       SpaceX      USA   50.00  Success
# 2019-03-09         CASC    China   29.15  Success
# 2019-03-22  Arianespace   France   37.00  Success

# %%
df['Company Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company Name'>

# %%
df['Company Name'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Company Name'>

# %%
df['Status'].value_counts().plot(kind='pie', legend=True)
# Out:
# <Axes: ylabel='count'>
