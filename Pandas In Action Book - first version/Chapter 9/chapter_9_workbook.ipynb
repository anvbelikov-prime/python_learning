# %%
import numpy as np
import pandas as pd

# %%
food_data = {
    'Item': ['Banana', 'Cucumber', 'Orange', 'Tomato', 'Watermelon'],
    'Type': ['Fruit', 'Vegetable', 'Fruit', 'Vegetable', 'Fruit'],
    'Price': [0.99, 1.25, 0.25, 0.33, 3.00]
}

# %%
supermarket = pd.DataFrame(food_data)
supermarket
# Out:
#          Item       Type  Price
# 0      Banana      Fruit   0.99
# 1    Cucumber  Vegetable   1.25
# 2      Orange      Fruit   0.25
# 3      Tomato  Vegetable   0.33
# 4  Watermelon      Fruit   3.00

# %%
groups = supermarket.groupby('Type')

# %%
groups

# %%
type(groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
groups.get_group('Fruit')
# Out:
#          Item   Type  Price
# 0      Banana  Fruit   0.99
# 2      Orange  Fruit   0.25
# 4  Watermelon  Fruit   3.00

# %%
groups.get_group('Vegetable')
# Out:
#        Item       Type  Price
# 1  Cucumber  Vegetable   1.25
# 3    Tomato  Vegetable   0.33

# %%
groups['Price'].mean()
# Out:
# Type
# Fruit        1.413333
# Vegetable    0.790000
# Name: Price, dtype: float64

# %%
fortune = pd.read_csv('fortune1000.csv')
fortune
# Out:
#                              Company  Revenues  Profits  Employees  \
# 0                            Walmart  500343.0   9862.0    2300000
# 1                        Exxon Mobil  244363.0  19710.0      71200
# 2                 Berkshire Hathaway  242137.0  44940.0     377000
# 3                              Apple  229234.0  48351.0     123000
# 4                 UnitedHealth Group  201159.0  10558.0     260000
# ..                               ...       ...      ...        ...
# 995         SiteOne Landscape Supply    1862.0     54.6       3664
# 996  Charles River Laboratories Intl    1858.0    123.4      11800
# 997                        CoreLogic    1851.0    152.2       5900
# 998                     Ensign Group    1849.0     40.5      21301
# 999                              HCP    1848.0    414.2        190
#
#                 Sector                                  Industry
# 0            Retailing                     General Merchandisers
# ...

# %%
retail_companies = fortune[fortune['Sector'] == 'Retailing']
retail_companies
# Out:
#                       Company  Revenues  Profits  Employees     Sector  \
# 0                     Walmart  500343.0   9862.0    2300000  Retailing
# 7                  Amazon.com  177866.0   3033.0     566000  Retailing
# 14                     Costco  129025.0   2679.0     182000  Retailing
# 22                 Home Depot  100904.0   8630.0     413000  Retailing
# 38                     Target   71879.0   2934.0     345000  Retailing
# ..                        ...       ...      ...        ...        ...
# 909      99 Cents Only Stores    2194.0    -90.3      17200  Retailing
# 926                   Express    2138.0     19.4       9576  Retailing
# 971               Finish Line    1934.0    -18.2       8200  Retailing
# 989  Barnes & Noble Education    1874.0      5.4      13375  Retailing
# 992           Childrens Place    1870.0     84.7       9800  Retailing
#
#                             Industry
# 0              General Merchandisers
# 7    Internet Services and Retailing
# ...

# %%
print(retail_companies['Revenues'].mean())
# Out:
# 21874.714285714286

# %%
fortune.pivot_table(index='Sector', values='Revenues', aggfunc='mean')
# Out:
#                                    Revenues
# Sector
# Aerospace & Defense            15353.400000
# Apparel                         7225.521429
# Business Services               5963.962264
# Chemicals                       7610.636364
# Energy                         14425.300935
# Engineering & Construction      6399.333333
# Financials                     15757.935484
# Food &  Drug Stores            33789.000000
# Food, Beverages & Tobacco      13790.054054
# Health Care                    21239.315493
# Hotels, Restaurants & Leisure   6916.346154
# Household Products              8277.850000
# Industrials                    10615.102041
# Materials                       6184.400000
# Media                           9219.496000
# Motor Vehicles & Parts         22817.631579
# Retailing                      21874.714286
# Technology                     13347.789320
# Telecommunications             46695.900000
# Transportation                 11379.000000
# ...

# %%
sectors = fortune.groupby('Sector')
sectors

# %%
len(sectors)
# Out:
# 21

# %%
fortune.nunique()
# Out:
# Company      1000
# Revenues      951
# Profits       971
# Employees     754
# Sector         21
# Industry       74
# dtype: int64

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense               25
# Apparel                           14
# Business Services                 53
# Chemicals                         33
# Energy                           107
# Engineering & Construction        27
# Financials                       155
# Food &  Drug Stores               12
# Food, Beverages & Tobacco         37
# Health Care                       71
# Hotels, Restaurants & Leisure     26
# Household Products                28
# Industrials                       49
# Materials                         45
# Media                             25
# Motor Vehicles & Parts            19
# Retailing                         77
# Technology                       103
# Telecommunications                10
# Transportation                    40
# Wholesalers                       44
# dtype: int64

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [26, 50, 58, 98, 117, 118, 207, 224, 275, 380, 404, 406, 414, 540, 660, 661, 806, 829, 884, 930, 954, 955, 959, 975, 988], 'Apparel': [88, 241, 331, 420, 432, 526, 529, 554, 587, 678, 766, 774, 835, 861], 'Business Services': [142, 160, 187, 199, 201, 221, 235, 242, 253, 295, 325, 358, 364, 423, 462, 465, 486, 493, 497, 499, 502, 510, 528, 567, 577, 584, 591, 599, 604, 618, 649, 686, 691, 692, 700, 702, 712, 720, 738, 744, 771, 802, 810, 825, 879, 888, 894, 895, 898, 905, 922, 972, 997], 'Chemicals': [46, 189, 190, 198, 214, 263, 281, 309, 344, 351, 381, 447, 450, 454, 527, 593, 623, 648, 671, 672, 679, 704, 722, 740, 790, 836, 865, 872, 908, 932, 958, 963, 978], 'Energy': [1, 12, 27, 30, 40, 63, 89, 90, 91, 94, 104, 114, 124, 125, 134, 145, 166, 167, 175, 184, 205, 212, 213, 217, 218, 219, 222, 231, 232, 243, 248, 254, 256, 265, 268, 269, 270, 273, 307, 313, 326, 333, 335, 343, 352, 363, 371, 379, 383, 384, 387, 428, 437, 452, 456, 488, 490, 496, 498, 500, 51
# ...

# %%
fortune.loc[26, 'Sector']
# Out:
# 'Aerospace & Defense'

# %%
sectors.first()
# Out:
#                                               Company  Revenues  Profits  \
# Sector
# Aerospace & Defense                            Boeing   93392.0   8197.0
# Apparel                                          Nike   34350.0   4240.0
# Business Services                       ManpowerGroup   21034.0    545.4
# Chemicals                                   DowDuPont   62683.0   1460.0
# Energy                                    Exxon Mobil  244363.0  19710.0
# Engineering & Construction                      Fluor   19521.0    191.4
# Financials                         Berkshire Hathaway  242137.0  44940.0
# Food &  Drug Stores                            Kroger  122662.0   1907.0
# Food, Beverages & Tobacco                     PepsiCo   63525.0   4857.0
# Health Care                        UnitedHealth Group  201159.0  10558.0
# Hotels, Restaurants & Leisure  Marriott International   22894.0   1372.0
# Household Products                   Procter & Gamble   66217.0  15326.0
# ...

# %%
sectors.last()
# Out:
#                                                    Company  Revenues  Profits  \
# Sector
# Aerospace & Defense            Aerojet Rocketdyne Holdings    1877.0     -9.2
# Apparel                               Wolverine World Wide    2350.0      0.3
# Business Services                                CoreLogic    1851.0    152.2
# Chemicals                                           Stepan    1925.0     91.6
# Energy                            Superior Energy Services    1874.0   -205.9
# Engineering & Construction                        TopBuild    1906.0    158.1
# Financials                                             HCP    1848.0    414.2
# Food &  Drug Stores                                  Freds    2064.0   -140.3
# Food, Beverages & Tobacco                        Universal    2071.0    106.3
# Health Care                                   Ensign Group    1849.0     40.5
# Hotels, Restaurants & Leisure                 Vail Resorts    1907.0    210.6
# ...

# %%
sectors.nth(0)
# Out:
#                     Company  Revenues  Profits  Employees  \
# 0                   Walmart  500343.0   9862.0    2300000
# 1               Exxon Mobil  244363.0  19710.0      71200
# 2        Berkshire Hathaway  242137.0  44940.0     377000
# 3                     Apple  229234.0  48351.0     123000
# 4        UnitedHealth Group  201159.0  10558.0     260000
# 5                  McKesson  198533.0   5070.0      64500
# 8                      AT&T  160546.0  29450.0     254000
# 9            General Motors  157311.0  -3864.0     180000
# 16                   Kroger  122662.0   1907.0     449000
# 17         General Electric  122274.0  -5786.0     313000
# 26                   Boeing   93392.0   8197.0     140800
# 41         Procter & Gamble   66217.0  15326.0      95000
# 43                      UPS   65872.0   4910.0     346415
# 44                  PepsiCo   63525.0   4857.0     263000
# 46                DowDuPont   62683.0   1460.0      98000
# ...

# %%
sectors.nth(2)
# Out:
#                       Company  Revenues  Profits  Employees  \
# 13            Cardinal Health  129976.0   1288.0      40400
# 14                     Costco  129025.0   2679.0     182000
# 20                 Fannie Mae  112394.0   2463.0       7200
# 24    Express Scripts Holding  100065.0   4517.4      26600
# 27                Phillips 66   91568.0   5106.0      14600
# 29                  Microsoft   89950.0  21204.0     124000
# 32                    Comcast   84526.0  22714.0     164000
# 52            Albertsons Cos.   59678.0   -373.3     273000
# 58            Lockheed Martin   51048.0   2002.0     100000
# 70    American Airlines Group   42207.0   1919.0     126600
# 76    Honeywell International   40534.0   1655.0     131000
# 79                Tyson Foods   38260.0   1774.0     122000
# 108  Twenty-First Century Fox   28500.0   2952.0      21700
# 131                 Starbucks   22387.0   2884.7     277000
# 147                      Lear   20467.0   1313.4     165000
# ...

# %%
sectors.nth(3)
# Out:
#                     Company  Revenues  Profits  Employees  \
# 22               Home Depot  100904.0   8630.0     413000
# 23    Bank of America Corp.  100264.0  18232.0     209376
# 28                   Anthem   90040.0   3842.8      56000
# 30            Valero Energy   88407.0   4065.0      10015
# 33                      IBM   79139.0   5753.0     397800
# 53                    Sysco   55371.0   1142.5      66500
# 73   Charter Communications   41581.0   9895.0      94800
# 74          Delta Air Lines   41244.0   3577.0      86564
# 86                Coca-Cola   35410.0   1248.0      61800
# 87     Publix Super Markets   34837.0   2291.9     193000
# 96                       3M   31657.0   4858.0      91536
# 98         General Dynamics   30973.0   2912.0      98600
# 186  Goodyear Tire & Rubber   15377.0    346.0      64000
# 195           Newell Brands   14742.0   2748.8      49000
# 196                     CBS   14710.0    357.0      14715
# ...

# %%
fortune[fortune['Sector'] == 'Apparel'].head()
# Out:
#           Company  Revenues  Profits  Employees   Sector Industry
# 88           Nike   34350.0   4240.0      74400  Apparel  Apparel
# 241            VF   12400.0    614.9      69000  Apparel  Apparel
# 331           PVH    8915.0    537.8      28050  Apparel  Apparel
# 420  Ralph Lauren    6653.0    -99.3      18250  Apparel  Apparel
# 432   Hanesbrands    6478.0     61.9      67200  Apparel  Apparel

# %%
sectors.first()
# Out:
#                                               Company  Revenues  Profits  \
# Sector
# Aerospace & Defense                            Boeing   93392.0   8197.0
# Apparel                                          Nike   34350.0   4240.0
# Business Services                       ManpowerGroup   21034.0    545.4
# Chemicals                                   DowDuPont   62683.0   1460.0
# Energy                                    Exxon Mobil  244363.0  19710.0
# Engineering & Construction                      Fluor   19521.0    191.4
# Financials                         Berkshire Hathaway  242137.0  44940.0
# Food &  Drug Stores                            Kroger  122662.0   1907.0
# Food, Beverages & Tobacco                     PepsiCo   63525.0   4857.0
# Health Care                        UnitedHealth Group  201159.0  10558.0
# Hotels, Restaurants & Leisure  Marriott International   22894.0   1372.0
# Household Products                   Procter & Gamble   66217.0  15326.0
# ...

# %%
sectors.head(2)
# Out:
#                       Company  Revenues  Profits  Employees  \
# 0                     Walmart  500343.0   9862.0    2300000
# 1                 Exxon Mobil  244363.0  19710.0      71200
# 2          Berkshire Hathaway  242137.0  44940.0     377000
# 3                       Apple  229234.0  48351.0     123000
# 4          UnitedHealth Group  201159.0  10558.0     260000
# 5                    McKesson  198533.0   5070.0      64500
# 6                  CVS Health  184765.0   6622.0     203000
# 7                  Amazon.com  177866.0   3033.0     566000
# 8                        AT&T  160546.0  29450.0     254000
# 9              General Motors  157311.0  -3864.0     180000
# 10                 Ford Motor  156776.0   7602.0     202000
# 11          AmerisourceBergen  153144.0    364.5      19500
# 12                    Chevron  134533.0   9195.0      51900
# 15                    Verizon  126034.0  30101.0     155400
# 16                     Kroger  122662.0   1907.0     449000
# ...

# %%
sectors.head(2).pivot_table(index='Sector', values='Revenues', aggfunc='count')
# Out:
#                                Revenues
# Sector
# Aerospace & Defense                   2
# Apparel                               2
# Business Services                     2
# Chemicals                             2
# Energy                                2
# Engineering & Construction            2
# Financials                            2
# Food &  Drug Stores                   2
# Food, Beverages & Tobacco             2
# Health Care                           2
# Hotels, Restaurants & Leisure         2
# Household Products                    2
# Industrials                           2
# Materials                             2
# Media                                 2
# Motor Vehicles & Parts                2
# Retailing                             2
# Technology                            2
# Telecommunications                    2
# Transportation                        2
# Wholesalers                           2

# %%
sectors.tail(3)
# Out:
#                              Company  Revenues  Profits  Employees  \
# 473              Windstream Holdings    5853.0  -2116.6      12979
# 520         Telephone & Data Systems    5044.0    153.0       9900
# 667                     Weis Markets    3467.0     98.4      23000
# 759             Hain Celestial Group    2853.0     67.4       7825
# 774                     Fossil Group    2788.0   -478.2      12300
# ..                               ...       ...      ...        ...
# 995         SiteOne Landscape Supply    1862.0     54.6       3664
# 996  Charles River Laboratories Intl    1858.0    123.4      11800
# 997                        CoreLogic    1851.0    152.2       5900
# 998                     Ensign Group    1849.0     40.5      21301
# 999                              HCP    1848.0    414.2        190
#
#                         Sector                                  Industry
# 473         Telecommunications                        Telecommunications
# ...

# %%
sectors.get_group('Energy')
# Out:
#                        Company  Revenues  Profits  Employees  Sector  \
# 1                  Exxon Mobil  244363.0  19710.0      71200  Energy
# 12                     Chevron  134533.0   9195.0      51900  Energy
# 27                 Phillips 66   91568.0   5106.0      14600  Energy
# 30               Valero Energy   88407.0   4065.0      10015  Energy
# 40          Marathon Petroleum   67610.0   3432.0      43800  Energy
# ..                         ...       ...      ...        ...     ...
# 953       California Resources    2006.0   -266.0       1450  Energy
# 976        Ferrellgas Partners    1930.0    -54.2       3891  Energy
# 979  Oceaneering International    1922.0    166.4       8200  Energy
# 980             Cimarex Energy    1918.0    494.3        910  Energy
# 990   Superior Energy Services    1874.0   -205.9       6400  Energy
#
#                             Industry
# 1                 Petroleum Refining
# 12                Petroleum Refining
# ...

# %%
sectors.sum()
# Out:
#                                                                          Company  \
# Sector
# Aerospace & Defense            BoeingUnited TechnologiesLockheed MartinGenera...
# Apparel                        NikeVFPVHRalph LaurenHanesbrandsUnder ArmourLe...
# Business Services              ManpowerGroupVisaOmnicom GroupAramarkWaste Man...
# Chemicals                      DowDuPontSherwin-WilliamsPPG IndustriesMonsant...
# Energy                         Exxon MobilChevronPhillips 66Valero EnergyMara...
# Engineering & Construction     FluorAECOMD.R. HortonLennarJacobs Engineering ...
# Financials                     Berkshire HathawayJPMorgan ChaseFannie MaeBank...
# Food &  Drug Stores            KrogerWalgreens Boots AllianceAlbertsons Cos.P...
# Food, Beverages & Tobacco      PepsiCoArcher Daniels MidlandTyson FoodsCoca-C...
# Health Care                    UnitedHealth GroupCVS HealthExpress Scripts Ho...
# ...

# %%
sectors['Revenues'].sum()
# Out:
# Sector
# Aerospace & Defense               383835.0
# Apparel                           101157.3
# Business Services                 316090.0
# Chemicals                         251151.0
# Energy                           1543507.2
# Engineering & Construction        172782.0
# Financials                       2442480.0
# Food &  Drug Stores               405468.0
# Food, Beverages & Tobacco         510232.0
# Health Care                      1507991.4
# Hotels, Restaurants & Leisure     179825.0
# Household Products                231779.8
# Industrials                       520140.0
# Materials                         278298.0
# Media                             230487.4
# Motor Vehicles & Parts            433535.0
# Retailing                        1684353.0
# Technology                       1374822.3
# Telecommunications                466959.0
# Transportation                    455160.0
# Wholesalers                       888149.0
# Name: Revenues, dtype: float64

# %%
sectors[['Revenues', 'Profits']].sum()
# Out:
#                                 Revenues   Profits
# Sector
# Aerospace & Defense             383835.0   26733.5
# Apparel                         101157.3    6350.7
# Business Services               316090.0   37179.2
# Chemicals                       251151.0   20475.0
# Energy                         1543507.2   85369.6
# Engineering & Construction      172782.0    7121.0
# Financials                     2442480.0  264253.5
# Food &  Drug Stores             405468.0    8440.3
# Food, Beverages & Tobacco       510232.0   54902.5
# Health Care                    1507991.4   92791.1
# Hotels, Restaurants & Leisure   179825.0   21305.5
# Household Products              231779.8   27726.8
# Industrials                     520140.0   19114.3
# Materials                       278298.0   13730.4
# Media                           230487.4   23019.9
# Motor Vehicles & Parts          433535.0    6861.1
# Retailing                      1684353.0   55707.2
# ...

# %%
sectors['Revenues'].mean()
# Out:
# Sector
# Aerospace & Defense              15353.400000
# Apparel                           7225.521429
# Business Services                 5963.962264
# Chemicals                         7610.636364
# Energy                           14425.300935
# Engineering & Construction        6399.333333
# Financials                       15757.935484
# Food &  Drug Stores              33789.000000
# Food, Beverages & Tobacco        13790.054054
# Health Care                      21239.315493
# Hotels, Restaurants & Leisure     6916.346154
# Household Products                8277.850000
# Industrials                      10615.102041
# Materials                         6184.400000
# Media                             9219.496000
# Motor Vehicles & Parts           22817.631579
# Retailing                        21874.714286
# Technology                       13347.789320
# Telecommunications               46695.900000
# Transportation                   11379.000000
# ...

# %%
sectors.max()
# Out:
#                                               Company  Revenues  Profits  \
# Sector
# Aerospace & Defense                          Woodward   93392.0   8197.0
# Apparel                          Wolverine World Wide   34350.0   4240.0
# Business Services                            Worldpay   21034.0   6699.0
# Chemicals                           Westlake Chemical   62683.0   3000.4
# Energy                                    Xcel Energy  244363.0  19710.0
# Engineering & Construction               Tutor Perini   19521.0   1038.4
# Financials                             Zions Bancorp.  242137.0  44940.0
# Food &  Drug Stores                      Weis Markets  122662.0   4078.0
# Food, Beverages & Tobacco                   Universal   63525.0  10999.0
# Health Care                                    Zoetis  201159.0  21308.0
# Hotels, Restaurants & Leisure      Yum China Holdings   22894.0   5192.3
# Household Products                      Vista Outdoor   66217.0  15326.0
# ...

# %%
sectors['Employees'].min()
# Out:
# Sector
# Aerospace & Defense              5157
# Apparel                          3700
# Business Services                2338
# Chemicals                        1931
# Energy                            593
# Engineering & Construction       1100
# Financials                        152
# Food &  Drug Stores              7324
# Food, Beverages & Tobacco        1819
# Health Care                      2298
# Hotels, Restaurants & Leisure    8600
# Household Products               4050
# Industrials                      4125
# Materials                         126
# Media                            2039
# Motor Vehicles & Parts           2700
# Retailing                        2505
# Technology                       2100
# Telecommunications               3794
# Transportation                   1273
# Wholesalers                       981
# Name: Employees, dtype: int64

# %%
sectors.agg({'Revenues': 'min', 'Profits': 'max', 'Employees': 'mean'})
# Out:
#                                Revenues  Profits      Employees
# Sector
# Aerospace & Defense              1877.0   8197.0   40404.960000
# Apparel                          2350.0   4240.0   25407.071429
# Business Services                1851.0   6699.0   30075.452830
# Chemicals                        1925.0   3000.4   14364.242424
# Energy                           1874.0  19710.0    9170.158879
# Engineering & Construction       1906.0   1038.4   15583.148148
# Financials                       1848.0  44940.0   22581.412903
# Food &  Drug Stores              2064.0   4078.0  116506.166667
# Food, Beverages & Tobacco        2071.0  10999.0   29170.702703
# Health Care                      1849.0  21308.0   41847.732394
# Hotels, Restaurants & Leisure    1907.0   5192.3   88628.346154
# Household Products               1949.0  15326.0   24103.428571
# Industrials                      1918.0   4858.0   31961.428571
# Materials                        1933.0   2144.0   14527.800000
# ...

# %%
fortune.nlargest(n=5, columns='Profits')
# Out:
#                Company  Revenues  Profits  Employees              Sector  \
# 3                Apple  229234.0  48351.0     123000          Technology
# 2   Berkshire Hathaway  242137.0  44940.0     377000          Financials
# 15             Verizon  126034.0  30101.0     155400  Telecommunications
# 8                 AT&T  160546.0  29450.0     254000  Telecommunications
# 19      JPMorgan Chase  113899.0  24441.0     252539          Financials
#
#                                     Industry
# 3                Computers, Office Equipment
# 2   Insurance: Property and Casualty (Stock)
# 15                        Telecommunications
# 8                         Telecommunications
# 19                          Commercial Banks

# %%
def get_largest_row(df):
    return df.nlargest(1, 'Revenues')

# %%
sectors[['Company', 'Revenues', 'Profits', 'Employees', 'Industry']].apply(get_largest_row)
# Out:
#                                                   Company  Revenues  Profits  \
# Sector
# Aerospace & Defense           26                   Boeing   93392.0   8197.0
# Apparel                       88                     Nike   34350.0   4240.0
# Business Services             142           ManpowerGroup   21034.0    545.4
# Chemicals                     46                DowDuPont   62683.0   1460.0
# Energy                        1               Exxon Mobil  244363.0  19710.0
# Engineering & Construction    152                   Fluor   19521.0    191.4
# Financials                    2        Berkshire Hathaway  242137.0  44940.0
# Food &  Drug Stores           16                   Kroger  122662.0   1907.0
# Food, Beverages & Tobacco     44                  PepsiCo   63525.0   4857.0
# Health Care                   4        UnitedHealth Group  201159.0  10558.0
# Hotels, Restaurants & Leisure 126  Marriott International   22894.0   1372.0
# ...

# %%
si = fortune.groupby(by=['Sector', 'Industry'])

# %%
si

# %%
si.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            25
# Apparel              Apparel                                          14
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         2
#                                                                       ..
# Transportation       Trucking, Truck Leasing                          11
# Wholesalers          Wholesalers: Diversified                         24
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
#                      Wholesalers: Health Care                          6
# Length: 82, dtype: int64

# %%
si.groups
# Out:
# {('Aerospace & Defense', 'Aerospace and Defense'): [26, 50, 58, 98, 117, 118, 207, 224, 275, 380, 404, 406, 414, 540, 660, 661, 806, 829, 884, 930, 954, 955, 959, 975, 988], ('Apparel', 'Apparel'): [88, 241, 331, 420, 432, 526, 529, 554, 587, 678, 766, 774, 835, 861], ('Business Services', 'Advertising, marketing'): [187, 358], ('Business Services', 'Diversified Outsourcing Services'): [199, 242, 465, 497, 499, 577, 618, 691, 692, 700, 702, 712, 744, 771], ('Business Services', 'Education'): [567, 810], ('Business Services', 'Financial Data Services'): [160, 221, 235, 253, 325, 364, 462, 486, 493, 528, 584, 591, 599, 604, 686, 879, 894, 895, 898, 905, 922, 972, 997], ('Business Services', 'Miscellaneous'): [423, 720, 888], ('Business Services', 'Temporary Help'): [142, 502, 510, 802, 825], ('Business Services', 'Waste Management'): [201, 295, 649, 738], ('Chemicals', 'Chemicals'): [46, 189, 190, 198, 214, 263, 281, 309, 344, 351, 381, 447, 450, 454, 527, 593, 623, 648, 671, 672, 679,
# ...

# %%
si.get_group(('Retailing', 'General Merchandisers'))
# Out:
#             Company  Revenues  Profits  Employees     Sector  \
# 0           Walmart  500343.0   9862.0    2300000  Retailing
# 14           Costco  129025.0   2679.0     182000  Retailing
# 38           Target   71879.0   2934.0     345000  Retailing
# 119           Macys   24837.0   1547.0     130000  Retailing
# 156           Kohls   19095.0    859.0      85000  Retailing
# 171  Sears Holdings   16702.0   -383.0      89000  Retailing
# 182       Nordstrom   15478.0    437.0      76000  Retailing
# 234     J.C. Penney   12506.0   -116.0      98000  Retailing
# 438        Dillards    6423.0    221.3      31400  Retailing
# 732      PriceSmart    2997.0     90.7       7903  Retailing
# 822  Bon-Ton Stores    2541.0    -90.7      23300  Retailing
#
#                   Industry
# 0    General Merchandisers
# 14   General Merchandisers
# 38   General Merchandisers
# 119  General Merchandisers
# 156  General Merchandisers
# 171  General Merchandisers
# 182  General Merchandisers
# ...

# %%
si['Profits'].sum()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            26733.5
# Apparel              Apparel                                           6350.7
# Business Services    Advertising, marketing                            1667.4
#                      Diversified Outsourcing Services                  5043.7
#                      Education                                          393.5
#                                                                        ...
# Transportation       Trucking, Truck Leasing                           3535.5
# Wholesalers          Wholesalers: Diversified                          5231.5
#                      Wholesalers: Electronics and Office Equipment     1259.4
#                      Wholesalers: Food and Grocery                     1794.0
#                      Wholesalers: Health Care                          7372.5
# Name: Profits, Length: 82, dtype: float64

# %%
# Homework

# %%
df = pd.read_csv('cereals.csv')
df
# Out:
#                          Name    Manufacturer  Type  Calories  Fiber  Sugars
# 0                   100% Bran         Nabisco  Cold        70   10.0       6
# 1           100% Natural Bran     Quaker Oats  Cold       120    2.0       8
# 2                    All-Bran       Kellogg's  Cold        70    9.0       5
# 3   All-Bran with Extra Fiber       Kellogg's  Cold        50   14.0       0
# 4              Almond Delight  Ralston Purina  Cold       110    1.0       8
# ..                        ...             ...   ...       ...    ...     ...
# 72                    Triples   General Mills  Cold       110    0.0       3
# 73                       Trix   General Mills  Cold       110    0.0      12
# 74                 Wheat Chex  Ralston Purina  Cold       100    3.0       3
# 75                   Wheaties   General Mills  Cold       100    3.0       3
# 76        Wheaties Honey Gold   General Mills  Cold       110    1.0       8
#
# [77 rows x 6 columns]

# %%
len(df)
# Out:
# 77

# %%
df.count()
# Out:
# Name            77
# Manufacturer    77
# Type            77
# Calories        77
# Fiber           77
# Sugars          77
# dtype: int64

# %%
df.nunique()
# Out:
# Name            77
# Manufacturer     7
# Type             2
# Calories        11
# Fiber           13
# Sugars          17
# dtype: int64

# %%
df['Type'].unique()
# Out:
# array(['Cold', 'Hot'], dtype=object)

# %%
# 1
man = df.groupby(by='Manufacturer')

# %%
man

# %%
# 2
len(man)
# Out:
# 7

# %%
man.size()
# Out:
# Manufacturer
# American Home Food Products     1
# General Mills                  22
# Kellogg's                      23
# Nabisco                         6
# Post                            9
# Quaker Oats                     8
# Ralston Purina                  8
# dtype: int64

# %%
man.size().sum()
# Out:
# np.int64(77)

# %%
# 3
man.get_group('Nabisco')
# Out:
#                          Name Manufacturer  Type  Calories  Fiber  Sugars
# 0                   100% Bran      Nabisco  Cold        70   10.0       6
# 20     Cream of Wheat (Quick)      Nabisco   Hot       100    1.0       0
# 63             Shredded Wheat      Nabisco  Cold        80    3.0       0
# 64     Shredded Wheat 'n'Bran      Nabisco  Cold        90    4.0       0
# 65  Shredded Wheat spoon size      Nabisco  Cold        90    3.0       0
# 68    Strawberry Fruit Wheats      Nabisco  Cold        90    3.0       5

# %%
# 4
man[['Calories', 'Fiber', 'Sugars']].mean()
# Out:
#                                Calories     Fiber    Sugars
# Manufacturer
# American Home Food Products  100.000000  0.000000  3.000000
# General Mills                111.363636  1.272727  7.954545
# Kellogg's                    108.695652  2.739130  7.565217
# Nabisco                       86.666667  4.000000  1.833333
# Post                         108.888889  2.777778  8.777778
# Quaker Oats                   95.000000  1.337500  5.250000
# Ralston Purina               115.000000  1.875000  6.125000

# %%
# 5
man['Sugars'].max()
# Out:
# Manufacturer
# American Home Food Products     3
# General Mills                  14
# Kellogg's                      15
# Nabisco                         6
# Post                           15
# Quaker Oats                    12
# Ralston Purina                 11
# Name: Sugars, dtype: int64

# %%
# 6
man['Fiber'].min()
# Out:
# Manufacturer
# American Home Food Products    0.0
# General Mills                  0.0
# Kellogg's                      0.0
# Nabisco                        1.0
# Post                           0.0
# Quaker Oats                    0.0
# Ralston Purina                 0.0
# Name: Fiber, dtype: float64

# %%
# 7
def get_less_sugar(df):
    return df.nsmallest(n=1, columns='Sugars')

# %%
man[['Name', 'Type', 'Calories', 'Fiber', 'Sugars']].apply(get_less_sugar)
# Out:
#                                                      Name  Type  Calories  \
# Manufacturer
# American Home Food Products 43                      Maypo   Hot       100
# General Mills               11                   Cheerios  Cold       110
# Kellogg's                   3   All-Bran with Extra Fiber  Cold        50
# Nabisco                     20     Cream of Wheat (Quick)   Hot       100
# Post                        33                 Grape-Nuts  Cold       110
# Quaker Oats                 57             Quaker Oatmeal   Hot       100
# Ralston Purina              61                  Rice Chex  Cold       110
#
#                                 Fiber  Sugars
# Manufacturer
# American Home Food Products 43    0.0       3
# General Mills               11    2.0       1
# Kellogg's                   3    14.0       0
# Nabisco                     20    1.0       0
# Post                        33    3.0       3
# Quaker Oats                 57    2.7      -1
# ...
