# %%
import numpy as np
import pandas as pd

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
ice_cream_flavors = [
    'vanilla',
    'orange',
    'watermelon',
    'milk',
    'original'
]

# %%
pd.Series(ice_cream_flavors)
# Out:
# 0       vanilla
# 1        orange
# 2    watermelon
# 3          milk
# 4      original
# dtype: object

# %%
days_of_week = (
    'Monday',
    'Tuesday',
    'Wednesday',
    'Thursday',
    'Friday'
)

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week)
# Out:
# Monday          vanilla
# Tuesday          orange
# Wednesday    watermelon
# Thursday           milk
# Friday         original
# dtype: object

# %%
# Индекс может повторяться

# %%
days_of_week_with_dublicates = [
    'Monday',
    'Tuesday',
    'Wednesday',
    'Wednesday',
    'Friday'
]

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates)
# Out:
# Monday          vanilla
# Tuesday          orange
# Wednesday    watermelon
# Wednesday          milk
# Friday         original
# dtype: object

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates)[1]
# Out:
# /var/folders/ly/4m8_p07j62l8tfy4gs_lj7100000gn/T/ipykernel_1869/53082552.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates)[1]
# 'orange'

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates).iloc[1]
# Out:
# 'orange'

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates).iloc[[1, 3]]
# Out:
# Tuesday      orange
# Wednesday      milk
# dtype: object

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates).loc['Wednesday']
# Out:
# Wednesday    watermelon
# Wednesday          milk
# dtype: object

# %%
pd.Series(data=ice_cream_flavors, index=days_of_week_with_dublicates).loc[['Wednesday', 'Monday']]
# Out:
# Wednesday    watermelon
# Wednesday          milk
# Monday          vanilla
# dtype: object

# %%
bunch_of_bools = [True, True, False, True]
lucky_numbers = [320, 667, 677, 994, 995, 629, 117]

# %%
pd.Series(bunch_of_bools)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
pd.Series(lucky_numbers)
# Out:
# 0    320
# 1    667
# 2    677
# 3    994
# 4    995
# 5    629
# 6    117
# dtype: int64

# %%
pd.Series(lucky_numbers, dtype='float')
# Out:
# 0    320.0
# 1    667.0
# 2    677.0
# 3    994.0
# 4    995.0
# 5    629.0
# 6    117.0
# dtype: float64

# %%
pd.Series(lucky_numbers, dtype='bool')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# dtype: bool

# %%
pd.Series(lucky_numbers, dtype=np.float64)
# Out:
# 0    320.0
# 1    667.0
# 2    677.0
# 3    994.0
# 4    995.0
# 5    629.0
# 6    117.0
# dtype: float64

# %%
temperatures = [15, 18, 25, 23, np.nan, 19, 27, 32, 35]

# %%
pd.Series(temperatures)
# Out:
# 0    15.0
# 1    18.0
# 2    25.0
# 3    23.0
# 4     NaN
# 5    19.0
# 6    27.0
# 7    32.0
# 8    35.0
# dtype: float64

# %%
my_dict = {
    'a':1,
    'b':2,
    'c':3
}

# %%
pd.Series(my_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
my_dict_new = {
    'a':1,
    'b':[2, 3]
}

# %%
my_dict_new
# Out:
# {'a': 1, 'b': [2, 3]}

# %%
pd.Series(my_dict_new)
# Out:
# a         1
# b    [2, 3]
# dtype: object

# %%
# Будет ошибка!!!
# pd.Series(my_dict_new, dtype=np.int64)

# %%
rgb_color = (10, 120, 100)

# %%
pd.Series(rgb_color)
# Out:
# 0     10
# 1    120
# 2    100
# dtype: int64

# %%
rgb_colors = [
    (10, 56, 234),
    (78, 23, 120),
    (56, 67, 34)
]

# %%
pd.Series(rgb_colors)
# Out:
# 0    (10, 56, 234)
# 1    (78, 23, 120)
# 2     (56, 67, 34)
# dtype: object

# %%
my_set = {'a', 'b', 'c'}

# %%
type(my_set)
# Out:
# set

# %%
pd.Series(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 pd.Series(my_set)
#
# File /opt/anaconda3/envs/current/lib/python3.13/site-packages/pandas/core/series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File /opt/anaconda3/envs/current/lib/python3.13/site-packages/pandas/core/construction.py:639, in sanitize_array(data, index, dtype, copy, allow_2d)
#     630     return sanitize_array(
#     631         data,
#     632         index=index,
#    (...)    635         allow_2d=allow_2d,
#     636     )
#     638 else:
# --> 639     _sanitize_non_ordered(data)
# ...

# %%
pd.Series(list(my_set))
# Out:
# 0    b
# 1    c
# 2    a
# dtype: object

# %%
random_data = np.random.randint(1, 101, 10)

# %%
random_data
# Out:
# array([80, 49, 51, 20, 23, 29,  3, 61, 38, 10])

# %%
pd.Series(random_data)
# Out:
# 0    80
# 1    49
# 2    51
# 3    20
# 4    23
# 5    29
# 6     3
# 7    61
# 8    38
# 9    10
# dtype: int64

# %%
pd.Series(random_data, random_data)
# Out:
# 80    80
# 49    49
# 51    51
# 20    20
# 23    23
# 29    29
# 3      3
# 61    61
# 38    38
# 10    10
# dtype: int64

# %%
my_series = pd.Series(my_dict)

# %%
my_series
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
my_series.dtype
# Out:
# dtype('int64')

# %%
my_series.values
# Out:
# array([1, 2, 3])

# %%
type(my_series.values)
# Out:
# numpy.ndarray

# %%
my_series.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
type(my_series.index)
# Out:
# pandas.core.indexes.base.Index

# %%
my_series.size
# Out:
# 3

# %%
my_series.shape
# Out:
# (3,)

# %%
my_series.is_unique
# Out:
# True

# %%
pd.Series(days_of_week_with_dublicates).is_unique
# Out:
# False

# %%
pd.Series([1, 2, 5, 7, 12]).is_monotonic_increasing
# Out:
# True

# %%
pd.Series([1, 2, 5, 7, 12]).is_monotonic_decreasing
# Out:
# False

# %%
pd.Series([1, 5, 3]).is_monotonic_increasing
# Out:
# False

# %%
pd.Series([1, 5, 3]).is_monotonic_decreasing
# Out:
# False

# %%
big_series = pd.Series(range(0, 500, 5))
big_series
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
big_series.is_unique
# Out:
# True

# %%
big_series.head(10)
# Out:
# 0     0
# 1     5
# 2    10
# 3    15
# 4    20
# 5    25
# 6    30
# 7    35
# 8    40
# 9    45
# dtype: int64

# %%
big_series.tail(15)
# Out:
# 85    425
# 86    430
# 87    435
# 88    440
# 89    445
# 90    450
# 91    455
# 92    460
# 93    465
# 94    470
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
numbers = pd.Series(np.array([1, 2, 3, np.nan, 4, 5]))

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
print(numbers.count())
# Out:
# 5

# %%
numbers.sum()
# Out:
# np.float64(15.0)

# %%
numbers.sum(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.sum(skipna=True, min_count=5)
# Out:
# np.float64(15.0)

# %%
numbers.sum(skipna=True, min_count=6)
# Out:
# np.float64(nan)

# %%
len(numbers)
# Out:
# 6

# %%
numbers.size
# Out:
# 6

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
numbers.product(skipna=True, min_count=3)
# Out:
# np.float64(120.0)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna=False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.pct_change()
# Out:
# /var/folders/ly/4m8_p07j62l8tfy4gs_lj7100000gn/T/ipykernel_1869/527026991.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers.pct_change(fill_method='ffill')
# Out:
# /var/folders/ly/4m8_p07j62l8tfy4gs_lj7100000gn/T/ipykernel_1869/3313576541.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='ffill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers.pct_change(fill_method='bfill')
# Out:
# /var/folders/ly/4m8_p07j62l8tfy4gs_lj7100000gn/T/ipykernel_1869/629865841.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='bfill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
numbers.bfill().pct_change()
# Out:
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
numbers.mean()
# Out:
# np.float64(3.0)

# %%
numbers.median()
# Out:
# 3.0

# %%
numbers.max()
# Out:
# 5.0

# %%
numbers.min()
# Out:
# 1.0

# %%
numbers.mean()
# Out:
# np.float64(3.0)

# %%
type(numbers.max())
# Out:
# float

# %%
numbers.std()
# Out:
# 1.5811388300841898

# %%
animals = pd.Series(['koala', 'crocodile', 'elephant', 'zebra'])

# %%
animals
# Out:
# 0        koala
# 1    crocodile
# 2     elephant
# 3        zebra
# dtype: object

# %%
animals.max()
# Out:
# 'zebra'

# %%
animals.min()
# Out:
# 'crocodile'

# %%
# Ошибка!!!
# animals.mean()

# %%
numbers.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
numbers.sample(3)
# Out:
# 0    1.0
# 4    4.0
# 2    3.0
# dtype: float64

# %%
numbers.sample(2)
# Out:
# 2    3.0
# 3    NaN
# dtype: float64

# %%
numbers.sample(2)
# Out:
# 5    5.0
# 3    NaN
# dtype: float64

# %%
numbers.sample(2)
# Out:
# 2    3.0
# 0    1.0
# dtype: float64

# %%
authors = ['Chekhov', 'Chekhov', 'Tolstoy', 'Medvedev', 'Belikov', 'Tolstoy']

# %%
authors_series = pd.Series(authors)

# %%
authors_series
# Out:
# 0     Chekhov
# 1     Chekhov
# 2     Tolstoy
# 3    Medvedev
# 4     Belikov
# 5     Tolstoy
# dtype: object

# %%
authors_series.unique()
# Out:
# array(['Chekhov', 'Tolstoy', 'Medvedev', 'Belikov'], dtype=object)

# %%
authors_series.is_unique
# Out:
# False

# %%
authors_series.nunique()
# Out:
# 4

# %%
len(authors_series)
# Out:
# 6

# %%
s1 = pd.Series([5, np.nan, 15], ['A', 'B', 'C'])
s1
# Out:
# A     5.0
# B     NaN
# C    15.0
# dtype: float64

# %%
s1.add(3)
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1 + 3
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1 - 5
# Out:
# A     0.0
# B     NaN
# C    10.0
# dtype: float64

# %%
s1.sub(5)
# Out:
# A     0.0
# B     NaN
# C    10.0
# dtype: float64

# %%
s1 * 3
# Out:
# A    15.0
# B     NaN
# C    45.0
# dtype: float64

# %%
s1.mul(3)
# Out:
# A    15.0
# B     NaN
# C    45.0
# dtype: float64

# %%
s1 / 2
# Out:
# A    2.5
# B    NaN
# C    7.5
# dtype: float64

# %%
s1.div(2)
# Out:
# A    2.5
# B    NaN
# C    7.5
# dtype: float64

# %%
s1 // 3
# Out:
# A    1.0
# B    NaN
# C    5.0
# dtype: float64

# %%
s1.floordiv(3)
# Out:
# A    1.0
# B    NaN
# C    5.0
# dtype: float64

# %%
s1 % 3
# Out:
# A    2.0
# B    NaN
# C    0.0
# dtype: float64

# %%
s1.mod(3)
# Out:
# A    2.0
# B    NaN
# C    0.0
# dtype: float64

# %%
s1 = pd.Series([1, 2, 3], index=['a', 'b', 'c'])
s2 = pd.Series([4, 5, 6], index=['a', 'b', 'c'])

# %%
s1 + s2
# Out:
# a    5
# b    7
# c    9
# dtype: int64

# %%
s1 - s2
# Out:
# a   -3
# b   -3
# c   -3
# dtype: int64

# %%
s1 == s2
# Out:
# a    False
# b    False
# c    False
# dtype: bool

# %%
s1 = pd.Series([3, 6, np.nan, 12])
s2 = pd.Series([2, 6, np.nan, 12])

# %%
s1
# Out:
# 0     3.0
# 1     6.0
# 2     NaN
# 3    12.0
# dtype: float64

# %%
s2
# Out:
# 0     2.0
# 1     6.0
# 2     NaN
# 3    12.0
# dtype: float64

# %%
s1 == s2
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1 != s2
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s1 = pd.Series([5, 10, 15], index=['a', 'b', 'c'])
s2 = pd.Series([4, 8, 12, 14], index=['b', 'c', 'd', 'e'])

# %%
s1
# Out:
# a     5
# b    10
# c    15
# dtype: int64

# %%
s2
# Out:
# b     4
# c     8
# d    12
# e    14
# dtype: int64

# %%
s1 + s2
# Out:
# a     NaN
# b    14.0
# c    23.0
# d     NaN
# e     NaN
# dtype: float64

# %%
cities = pd.Series(['San Francisco', 'Los Angeles', 'Las Vegas', np.nan])

# %%
cities.head()
# Out:
# 0    San Francisco
# 1      Los Angeles
# 2        Las Vegas
# 3              NaN
# dtype: object

# %%
cities
# Out:
# 0    San Francisco
# 1      Los Angeles
# 2        Las Vegas
# 3              NaN
# dtype: object

# %%
len(cities)
# Out:
# 4

# %%
type(cities)
# Out:
# pandas.core.series.Series

# %%
dir(cities)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
for c in cities:
    print(c, type(c), sep='\t')
# Out:
# San Francisco	<class 'str'>
# Los Angeles	<class 'str'>
# Las Vegas	<class 'str'>
# nan	<class 'float'>

# %%
dict(cities)
# Out:
# {0: 'San Francisco', 1: 'Los Angeles', 2: 'Las Vegas', 3: nan}

# %%
0 in cities
# Out:
# True

# %%
'Las Vegas' in cities
# Out:
# False

# %%
'Las Vegas' in cities.values
# Out:
# True

# %%
# homework

# %%
superheroes = [
    'Batman',
    'Superman',
    'Spider-Man',
    'Iron Man',
    'Captain America',
    'Wonder Woman'
]

strength_levels = (100, 120, 90, 95, 110, 120)

# %%
# 1
heroes = pd.Series(superheroes)

# %%
heroes
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-Man
# 3           Iron Man
# 4    Captain America
# 5       Wonder Woman
# dtype: object

# %%
# 2
strengths = pd.Series(strength_levels)

# %%
strengths
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
# 3
len(heroes) == len(strengths)
# Out:
# True

# %%
heroes = pd.Series(data=strength_levels, index=superheroes)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
# 4
heroes.head(2)
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
# 5
heroes.tail(4)
# Out:
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
# 6
heroes.is_unique
# Out:
# False

# %%
heroes.unique()
# Out:
# array([100, 120,  90,  95, 110])

# %%
len(heroes)
# Out:
# 6

# %%
heroes.nunique()
# Out:
# 5

# %%
# 7
print(heroes.mean())
# Out:
# 105.83333333333333

# %%
# 8
print(f'min strength: {heroes.min()}, max strength: {heroes.max()}')
# Out:
# min strength: 90, max strength: 120

# %%
# 9
heroes * 2
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
# 10
dict(heroes)
# Out:
# {'Batman': np.int64(100),
#  'Superman': np.int64(120),
#  'Spider-Man': np.int64(90),
#  'Iron Man': np.int64(95),
#  'Captain America': np.int64(110),
#  'Wonder Woman': np.int64(120)}

# %%
for k, v in heroes.items():
    print(k, v, sep='\t')
# Out:
# Batman	100
# Superman	120
# Spider-Man	90
# Iron Man	95
# Captain America	110
# Wonder Woman	120
