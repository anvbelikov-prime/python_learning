# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
space = pd.read_csv('space_missions.csv', parse_dates=['Date'], index_col='Date')
# Out:
# /var/folders/ly/4m8_p07j62l8tfy4gs_lj7100000gn/T/ipykernel_9246/1971978773.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   space = pd.read_csv('space_missions.csv', parse_dates=['Date'], index_col='Date')

# %%
space.head()
# Out:
#            Company Name Location    Cost   Status
# Date
# 2019-02-05  Arianespace   France  200.00  Success
# 2019-02-22       SpaceX      USA   50.00  Success
# 2019-03-02       SpaceX      USA   50.00  Success
# 2019-03-09         CASC    China   29.15  Success
# 2019-03-22  Arianespace   France   37.00  Success

# %%
space['Cost']
# Out:
# Date
# 2019-02-05    200.00
# 2019-02-22     50.00
# 2019-03-02     50.00
# 2019-03-09     29.15
# 2019-03-22     37.00
#                ...
# 2020-07-25     64.68
# 2020-07-30    145.00
# 2020-07-30     65.00
# 2020-08-06     29.75
# 2020-08-07     50.00
# Name: Cost, Length: 120, dtype: float64

# %%
space['Cost'].plot()
plt.show()

# %%
space.plot()
plt.show()

# %%
space.plot(y='Cost', colormap='gray')
plt.show()

# %%
space['Company Name'].value_counts().plot(kind='barh')
plt.show()

# %%
space['Status'].value_counts().plot(kind='pie', legend=True)
plt.show()
